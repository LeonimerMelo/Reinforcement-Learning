# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonimerMelo/Reinforcement-Learning/blob/Policy-Gradient/Advantage_Actor_Critic_(A2C_A3C)_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Advantage Actor-Critic (A2C e A3C)
#
# Os algoritmos **Advantage Actor-Critic (A2C e A3C)** são melhorias sobre o algoritmo básico de aprendizado por reforço **REINFORCE**. Os algoritmos Advantage Actor-Critic (A2C e A3C) são técnicas de aprendizado por reforço que combinam os métodos de política (actor) e valor (critic) de forma eficiente para treinar agentes em uma ampla variedade de tarefas. Eles são especialmente úteis em ambientes com alta dimensionalidade de estados e ações, e têm se mostrado eficazes em diversas aplicações, como jogos, robótica e controle de sistemas complexos.
#
# **Conceitos Fundamentais:**
#
# * **Actor:** Parte do algoritmo responsável por tomar as decisões, ou seja, escolher as ações a serem executadas em cada estado.
# * **Critic:** Parte do algoritmo responsável por avaliar a qualidade das ações escolhidas pelo actor, estimando o valor de cada estado e a vantagem de cada ação.
# * **Advantage:** A diferença entre o valor de uma ação e o valor médio de todas as ações possíveis em um determinado estado. Essa métrica ajuda a priorizar ações que levam a melhores resultados.
#
# **Diferenças entre A2C e A3C:**
#
# * **A2C (Advantage Actor-Critic):**
#     * Utiliza um único processo para atualizar os parâmetros do actor e do critic.
#     * É mais simples de implementar e geralmente apresenta um bom desempenho em muitos problemas.
#     * É mais adequado para ambientes com um único agente.
# * **A3C (Asynchronous Advantage Actor-Critic):**
#     * Utiliza múltiplos processos (ou threads) para atualizar os parâmetros em paralelo.
#     * Permite um treinamento mais rápido e estável, especialmente em ambientes complexos.
#     * É mais adequado para ambientes com múltiplos agentes ou quando a simulação do ambiente é lenta.
#
# **Funcionamento:**
#
# 1. **Inicialização:** Os parâmetros do actor e do critic são inicializados aleatoriamente.
# 2. **Interação com o ambiente:** O agente interage com o ambiente, coletando dados sobre os estados, ações e recompensas.
# 3. **Cálculo da vantagem:** A vantagem de cada ação é calculada com base na diferença entre o valor estimado do estado e o valor da ação.
# 4. **Atualização dos parâmetros:** Os parâmetros do actor e do critic são atualizados utilizando a técnica de gradiente descendente estocástico, com base na vantagem calculada.
# 5. **Repetição:** Os passos 2, 3 e 4 são repetidos por um número pré-definido de iterações ou até que um critério de parada seja atingido.
#
# **Vantagens dos Algoritmos A2C e A3C:**
#
# * **Convergência rápida:** Geralmente convergem para soluções de alta qualidade em um número menor de iterações.
# * **Flexibilidade:** Podem ser aplicados a uma ampla variedade de problemas de aprendizado por reforço.
# * **Estabilidade:** São relativamente estáveis e menos propensos a divergir durante o treinamento.
# * **Paralelização:** A3C permite a utilização de múltiplos núcleos de processamento, acelerando significativamente o treinamento.
#
# **Aplicações:**
#
# * **Jogos:** Dominaram diversas plataformas, como o Atari e o OpenAI Gym.
# * **Robótica:** Controle de robôs manipuladores, drones e veículos autônomos.
# * **Sistemas de recomendação:** Personalização de conteúdo e produtos para usuários.
# * **Finanças:** Previsão de séries temporais e otimização de portfólios.
#
# A escolha entre A2C e A3C depende da complexidade do problema, dos recursos computacionais disponíveis e das características do ambiente. Ambos os algoritmos são ferramentas poderosas para o desenvolvimento de agentes inteligentes e têm sido amplamente utilizados em diversas áreas da inteligência artificial.

# %% [markdown]
# Os algoritmos **Advantage Actor-Critic (A2C e A3C)** são melhorias sobre o algoritmo básico de aprendizado por reforço **REINFORCE**. Eles abordam algumas limitações do REINFORCE, como alta variância nos gradientes estimados e ineficiência na coleta de amostras. Abaixo explico como esses algoritmos funcionam e o que os diferencia:
#
# ---
#
# ## **REINFORCE: O Básico**
# O REINFORCE utiliza **gradiente de política** para atualizar os parâmetros da política (rede neural). O gradiente é estimado como:
#
# $$
# \nabla_\theta J(\theta) = \mathbb{E}_{\tau} \left[ \sum_{t} \nabla_\theta \log \pi_\theta(a_t | s_t) G_t \right]
# $$
#
# - $ \pi_\theta(a_t | s_t) $: Probabilidade de tomar a ação $ a_t $ dado o estado $ s_t $.
# - $ G_t $: Retorno acumulado futuro.
# - Ele é **off-policy** e de alta variância, dificultando o treinamento eficiente.
#
# ---
#
# ## **Problemas do REINFORCE**
# 1. **Alta Variância**: A utilização do retorno $ G_t $ diretamente no gradiente pode levar a variações grandes entre as atualizações.
# 2. **Atualizações Ineficientes**: Ele depende de trajetórias completas para estimar o gradiente, o que torna a aprendizagem lenta.
# 3. **Uso Subótimo de Informação**: O REINFORCE não separa a qualidade das ações em relação a outras possíveis ações (ou seja, não avalia as ações relativas ao baseline).
#
# ---
#
# ## **Advantage Actor-Critic (A2C/A3C)**
# Os algoritmos A2C e A3C introduzem várias melhorias para superar os problemas do REINFORCE:
#
# ### **1. Uso da Função Advantage**
# Os algoritmos A2C/A3C utilizam a função **Advantage** $ A(s, a) $, que mede a diferença entre a recompensa esperada ao tomar uma ação específica e a recompensa média no estado:
#
# $$
# A(s, a) = Q(s, a) - V(s)
# $$
#
# - $ Q(s, a) $: Valor esperado ao tomar a ação $ a $ no estado $ s $.
# - $ V(s) $: Valor esperado do estado $ s $ (baseline).
#
# Substituir $ G_t $ pela vantagem $ A(s, a) $ reduz a variância porque leva em conta a qualidade relativa de uma ação.
#
# O gradiente de política atualizado é:
#
# $$
# \nabla_\theta J(\theta) = \mathbb{E} \left[ \nabla_\theta \log \pi_\theta(a_t | s_t) A(s_t, a_t) \right]
# $$
#
# ---
#
# ### **2. Atualizações Sincronizadas (A2C) ou Assíncronas (A3C)**
# - **A2C (Advantage Actor-Critic):** Realiza atualizações de forma síncrona, coletando gradientes de múltiplos ambientes paralelos e agregando-os antes de atualizar a política.
# - **A3C (Asynchronous Advantage Actor-Critic):** Usa múltiplos trabalhadores assíncronos, que exploram o ambiente de forma independente e atualizam a política centralizada de maneira paralela.
#
# Esses métodos aumentam a eficiência computacional e melhoram a exploração, além de mitigar o problema de correlação entre as amostras.
#
# ---
#
# ### **3. Atualizações On-Policy**
# O A2C/A3C ainda é um algoritmo **on-policy**, mas utiliza gradientes mais precisos ao reduzir a variância por meio da função Advantage e da exploração paralela.
#
# ---
#
# ### **4. Atualizações Menores e Mais Frequentes**
# Ao contrário do REINFORCE, que usa trajetórias completas para calcular $ G_t $, o A2C/A3C usa **janelas temporais menores (n-steps)**, acumulando recompensas ao longo de $ n $ passos para estimar $ G_t $. Isso torna as atualizações mais rápidas e estáveis.
#
# $$
# G_t^{(n)} = \sum_{k=0}^{n-1} \gamma^k r_{t+k} + \gamma^n V(s_{t+n})
# $$
#
# ---
#
# ### **Resumo das Melhores do A2C/A3C sobre REINFORCE**
# 1. **Redução da Variância**: Uso da função Advantage $ A(s, a) $.
# 2. **Exploração Mais Eficiente**: Ambientes paralelos ou assíncronos.
# 3. **Treinamento Mais Estável**: Atualizações mais frequentes e baseadas em múltiplas amostras.
# 4. **Maior Eficiência Computacional**: Utilização de múltiplos trabalhadores.
#
# ---

# %% [markdown]
# ##Implementação A2C
# Exemplo básico de implementação do algoritmo **Advantage Actor-Critic (A2C)** em **PyTorch** utilizando `env gym CartPole-v1`

# %%
pip install gymnasium -q

# %%
# implementação do Advantage Actor-Critic (A2C) em PyTorch
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# Configurações
ENV_NAME = "CartPole-v1"
GAMMA = 0.99
LR = 1e-3
N_STEPS = 5
MAX_EPISODES = 1000

# Rede Actor-Critic
class ActorCritic(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.shared_layers = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
        )
        # Cabeça da Política (Ator)
        self.actor = nn.Sequential(
            nn.Linear(128, action_dim),
            nn.Softmax(dim=-1)
        )
        # Cabeça do Crítico (Valor)
        self.critic = nn.Linear(128, 1)

    def forward(self, state):
        shared = self.shared_layers(state)
        policy = self.actor(shared)
        value = self.critic(shared)
        return policy, value

# Agente A2C
class A2CAgent:
    def __init__(self, env):
        self.env = env
        self.state_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.n
        self.model = ActorCritic(self.state_dim, self.action_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=LR)

    def select_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0)
        policy, _ = self.model(state)
        action = torch.multinomial(policy, num_samples=1).item()
        return action

    def compute_advantage(self, rewards, values, next_value, dones):
        returns = []
        R = next_value
        for step in reversed(range(len(rewards))):
            R = rewards[step] + GAMMA * R * (1 - dones[step])
            returns.insert(0, R)
        returns = torch.tensor(returns)
        advantage = returns - values
        return returns, advantage

    def train(self, trajectory):
        states, actions, rewards, dones, next_state = trajectory
        states = torch.FloatTensor(states)
        actions = torch.LongTensor(actions)
        rewards = torch.FloatTensor(rewards)
        dones = torch.FloatTensor(dones)
        next_state = torch.FloatTensor(next_state).unsqueeze(0)

        # Predições do modelo
        _, next_value = self.model(next_state)
        policy, values = self.model(states)

        # Obtem a função Advantage
        values = values.squeeze()
        returns, advantage = self.compute_advantage(rewards, values, next_value.item(), dones)

        # Calcula perdas
        log_probs = torch.log(policy.gather(1, actions.unsqueeze(1)).squeeze())
        actor_loss = -(log_probs * advantage.detach()).mean()
        critic_loss = advantage.pow(2).mean()
        loss = actor_loss + critic_loss

        # Otimização
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# Loop de Treinamento
def train_a2c():
    env = gym.make(ENV_NAME)
    agent = A2CAgent(env)

    for episode in range(MAX_EPISODES):
        state, _ = env.reset()  # Gymnasium retorna estado e info
        trajectory = {"states": [], "actions": [], "rewards": [], "dones": []}
        episode_reward = 0

        for t in range(1, 10000):
            action = agent.select_action(state)
            next_state, reward, done, truncated, _ = env.step(action)

            # Certifique-se de que o estado é uma lista ou ndarray
            state = np.array(state, dtype=np.float32).tolist()
            next_state = np.array(next_state, dtype=np.float32).tolist()

            # Armazena a experiência
            trajectory["states"].append(state)
            trajectory["actions"].append(action)
            trajectory["rewards"].append(reward)
            trajectory["dones"].append(done or truncated)
            state = next_state
            episode_reward += reward

            # Atualiza o agente a cada N passos
            if len(trajectory["rewards"]) == N_STEPS or done or truncated:
                trajectory["next_state"] = state
                agent.train((
                    trajectory["states"],
                    trajectory["actions"],
                    trajectory["rewards"],
                    trajectory["dones"],
                    trajectory["next_state"]
                ))
                trajectory = {"states": [], "actions": [], "rewards": [], "dones": []}

            if done or truncated:
                print(f"Episode {episode}, Reward: {episode_reward}")
                break

    env.close()

# Treinando o agente
if __name__ == "__main__":
    train_a2c()
# Out:
# Episode 0, Reward: 18.0
# Episode 1, Reward: 19.0
# Episode 2, Reward: 45.0
# Episode 3, Reward: 16.0
# Episode 4, Reward: 23.0
# Episode 5, Reward: 15.0
# Episode 6, Reward: 21.0
# Episode 7, Reward: 14.0
# Episode 8, Reward: 47.0
# Episode 9, Reward: 13.0
# Episode 10, Reward: 15.0
# Episode 11, Reward: 9.0
# Episode 12, Reward: 38.0
# Episode 13, Reward: 11.0
# Episode 14, Reward: 18.0
# Episode 15, Reward: 34.0
# Episode 16, Reward: 13.0
# Episode 17, Reward: 40.0
# Episode 18, Reward: 30.0
# Episode 19, Reward: 26.0
# Episode 20, Reward: 37.0
# Episode 21, Reward: 12.0
# Episode 22, Reward: 26.0
# Episode 23, Reward: 29.0
# Episode 24, Reward: 17.0
# Episode 25, Reward: 10.0
# Episode 26, Reward: 22.0
# Episode 27, Reward: 28.0
# Episode 28, Reward: 12.0
# Episode 29, Reward: 20.0
# Episode 30, Reward: 18.0
# Episode 31, Reward: 21.0
# Episode 32, Reward: 17.0
# Episode 33, Reward: 15.0
# Episode 34, Reward: 22.0
# Episode 35, Reward: 14.0
# Episode 36, Reward: 27.0
# Episode 37, Reward: 23.0
# Episode 38, Reward: 19.0
# Episode 39, Reward: 12.0
# Episode 40, Reward: 12.0
# Episode 41, Reward: 24.0
# Episode 42, Reward: 15.0
# Episode 43, Reward: 11.0
# Episode 44, Reward: 16.0
# Episode 45, Reward: 20.0
# Episode 46, Reward: 11.0
# Episode 47, Reward: 14.0
# Episode 48, Reward: 14.0
# Episode 49, Reward: 17.0
# Episode 50, Reward: 31.0
# Episode 51, Reward: 15.0
# Episode 52, Reward: 8.0
# Episode 53, Reward: 18.0
# Episode 54, Reward: 11.0
# Episode 55, Reward: 8.0
# Episode 56, Reward: 14.0
# Episode 57, Reward: 16.0
# Episode 58, Reward: 8.0
# Episode 59, Reward: 10.0
# Episode 60, Reward: 10.0
# Episode 61, Reward: 10.0
# Episode 62, Reward: 15.0
# Episode 63, Reward: 12.0
# Episode 64, Reward: 14.0
# Episode 65, Reward: 9.0
# Episode 66, Reward: 11.0
# Episode 67, Reward: 13.0
# Episode 68, Reward: 9.0
# Episode 69, Reward: 12.0
# Episode 70, Reward: 8.0
# Episode 71, Reward: 10.0
# Episode 72, Reward: 12.0
# Episode 73, Reward: 14.0
# Episode 74, Reward: 9.0
# Episode 75, Reward: 13.0
# Episode 76, Reward: 12.0
# Episode 77, Reward: 12.0
# Episode 78, Reward: 10.0
# Episode 79, Reward: 10.0
# Episode 80, Reward: 10.0
# Episode 81, Reward: 11.0
# Episode 82, Reward: 12.0
# Episode 83, Reward: 9.0
# Episode 84, Reward: 9.0
# Episode 85, Reward: 12.0
# Episode 86, Reward: 12.0
# Episode 87, Reward: 9.0
# Episode 88, Reward: 9.0
# Episode 89, Reward: 14.0
# Episode 90, Reward: 9.0
# Episode 91, Reward: 14.0
# Episode 92, Reward: 12.0
# Episode 93, Reward: 25.0
# Episode 94, Reward: 13.0
# Episode 95, Reward: 12.0
# Episode 96, Reward: 10.0
# Episode 97, Reward: 11.0
# Episode 98, Reward: 10.0
# Episode 99, Reward: 12.0
# Episode 100, Reward: 9.0
# Episode 101, Reward: 16.0
# Episode 102, Reward: 12.0
# Episode 103, Reward: 21.0
# Episode 104, Reward: 10.0
# Episode 105, Reward: 11.0
# Episode 106, Reward: 9.0
# Episode 107, Reward: 10.0
# Episode 108, Reward: 13.0
# Episode 109, Reward: 11.0
# Episode 110, Reward: 12.0
# Episode 111, Reward: 11.0
# Episode 112, Reward: 14.0
# Episode 113, Reward: 9.0
# Episode 114, Reward: 11.0
# Episode 115, Reward: 14.0
# Episode 116, Reward: 12.0
# Episode 117, Reward: 16.0
# Episode 118, Reward: 11.0
# Episode 119, Reward: 17.0
# Episode 120, Reward: 11.0
# Episode 121, Reward: 19.0
# Episode 122, Reward: 9.0
# Episode 123, Reward: 8.0
# Episode 124, Reward: 12.0
# Episode 125, Reward: 11.0
# Episode 126, Reward: 13.0
# Episode 127, Reward: 12.0
# Episode 128, Reward: 16.0
# Episode 129, Reward: 23.0
# Episode 130, Reward: 13.0
# Episode 131, Reward: 18.0
# Episode 132, Reward: 22.0
# Episode 133, Reward: 13.0
# Episode 134, Reward: 13.0
# Episode 135, Reward: 12.0
# Episode 136, Reward: 16.0
# Episode 137, Reward: 30.0
# Episode 138, Reward: 10.0
# Episode 139, Reward: 28.0
# Episode 140, Reward: 17.0
# Episode 141, Reward: 30.0
# Episode 142, Reward: 11.0
# Episode 143, Reward: 16.0
# Episode 144, Reward: 25.0
# Episode 145, Reward: 14.0
# Episode 146, Reward: 23.0
# Episode 147, Reward: 17.0
# Episode 148, Reward: 20.0
# Episode 149, Reward: 13.0
# Episode 150, Reward: 18.0
# Episode 151, Reward: 26.0
# Episode 152, Reward: 18.0
# Episode 153, Reward: 11.0
# Episode 154, Reward: 13.0
# Episode 155, Reward: 10.0
# Episode 156, Reward: 10.0
# Episode 157, Reward: 9.0
# Episode 158, Reward: 14.0
# Episode 159, Reward: 11.0
# Episode 160, Reward: 13.0
# Episode 161, Reward: 14.0
# Episode 162, Reward: 13.0
# Episode 163, Reward: 38.0
# Episode 164, Reward: 17.0
# Episode 165, Reward: 13.0
# Episode 166, Reward: 32.0
# Episode 167, Reward: 20.0
# Episode 168, Reward: 17.0
# Episode 169, Reward: 19.0
# Episode 170, Reward: 46.0
# Episode 171, Reward: 24.0
# Episode 172, Reward: 19.0
# Episode 173, Reward: 49.0
# Episode 174, Reward: 19.0
# Episode 175, Reward: 24.0
# Episode 176, Reward: 35.0
# Episode 177, Reward: 41.0
# Episode 178, Reward: 27.0
# Episode 179, Reward: 81.0
# Episode 180, Reward: 30.0
# Episode 181, Reward: 20.0
# Episode 182, Reward: 16.0
# Episode 183, Reward: 25.0
# Episode 184, Reward: 16.0
# Episode 185, Reward: 33.0
# Episode 186, Reward: 32.0
# Episode 187, Reward: 17.0
# Episode 188, Reward: 12.0
# Episode 189, Reward: 15.0
# Episode 190, Reward: 14.0
# Episode 191, Reward: 20.0
# Episode 192, Reward: 43.0
# Episode 193, Reward: 23.0
# Episode 194, Reward: 59.0
# Episode 195, Reward: 41.0
# Episode 196, Reward: 24.0
# Episode 197, Reward: 32.0
# Episode 198, Reward: 45.0
# Episode 199, Reward: 18.0
# Episode 200, Reward: 21.0
# Episode 201, Reward: 31.0
# Episode 202, Reward: 18.0
# Episode 203, Reward: 28.0
# Episode 204, Reward: 10.0
# Episode 205, Reward: 31.0
# Episode 206, Reward: 25.0
# Episode 207, Reward: 21.0
# Episode 208, Reward: 23.0
# Episode 209, Reward: 29.0
# Episode 210, Reward: 18.0
# Episode 211, Reward: 50.0
# Episode 212, Reward: 39.0
# Episode 213, Reward: 50.0
# Episode 214, Reward: 25.0
# Episode 215, Reward: 58.0
# Episode 216, Reward: 28.0
# Episode 217, Reward: 54.0
# Episode 218, Reward: 18.0
# Episode 219, Reward: 29.0
# Episode 220, Reward: 19.0
# Episode 221, Reward: 56.0
# Episode 222, Reward: 26.0
# Episode 223, Reward: 40.0
# Episode 224, Reward: 25.0
# Episode 225, Reward: 26.0
# Episode 226, Reward: 22.0
# Episode 227, Reward: 30.0
# Episode 228, Reward: 20.0
# Episode 229, Reward: 51.0
# Episode 230, Reward: 19.0
# Episode 231, Reward: 48.0
# Episode 232, Reward: 14.0
# Episode 233, Reward: 23.0
# Episode 234, Reward: 17.0
# Episode 235, Reward: 25.0
# Episode 236, Reward: 52.0
# Episode 237, Reward: 21.0
# Episode 238, Reward: 29.0
# Episode 239, Reward: 24.0
# Episode 240, Reward: 85.0
# Episode 241, Reward: 32.0
# Episode 242, Reward: 32.0
# Episode 243, Reward: 14.0
# Episode 244, Reward: 24.0
# Episode 245, Reward: 27.0
# Episode 246, Reward: 27.0
# Episode 247, Reward: 13.0
# Episode 248, Reward: 20.0
# Episode 249, Reward: 17.0
# Episode 250, Reward: 28.0
# Episode 251, Reward: 30.0
# Episode 252, Reward: 15.0
# Episode 253, Reward: 11.0
# Episode 254, Reward: 17.0
# Episode 255, Reward: 19.0
# Episode 256, Reward: 25.0
# Episode 257, Reward: 17.0
# Episode 258, Reward: 17.0
# Episode 259, Reward: 23.0
# Episode 260, Reward: 15.0
# Episode 261, Reward: 19.0
# Episode 262, Reward: 29.0
# Episode 263, Reward: 18.0
# Episode 264, Reward: 14.0
# Episode 265, Reward: 26.0
# Episode 266, Reward: 125.0
# Episode 267, Reward: 54.0
# Episode 268, Reward: 52.0
# Episode 269, Reward: 72.0
# Episode 270, Reward: 69.0
# Episode 271, Reward: 57.0
# Episode 272, Reward: 152.0
# Episode 273, Reward: 23.0
# Episode 274, Reward: 21.0
# Episode 275, Reward: 38.0
# Episode 276, Reward: 50.0
# Episode 277, Reward: 49.0
# Episode 278, Reward: 83.0
# Episode 279, Reward: 19.0
# Episode 280, Reward: 22.0
# Episode 281, Reward: 85.0
# Episode 282, Reward: 145.0
# Episode 283, Reward: 61.0
# Episode 284, Reward: 90.0
# Episode 285, Reward: 61.0
# Episode 286, Reward: 39.0
# Episode 287, Reward: 40.0
# Episode 288, Reward: 39.0
# Episode 289, Reward: 79.0
# Episode 290, Reward: 18.0
# Episode 291, Reward: 42.0
# Episode 292, Reward: 13.0
# Episode 293, Reward: 145.0
# Episode 294, Reward: 61.0
# Episode 295, Reward: 34.0
# Episode 296, Reward: 31.0
# Episode 297, Reward: 37.0
# Episode 298, Reward: 27.0
# Episode 299, Reward: 25.0
# Episode 300, Reward: 22.0
# Episode 301, Reward: 13.0
# Episode 302, Reward: 23.0
# Episode 303, Reward: 36.0
# Episode 304, Reward: 34.0
# Episode 305, Reward: 41.0
# Episode 306, Reward: 24.0
# Episode 307, Reward: 20.0
# Episode 308, Reward: 49.0
# Episode 309, Reward: 174.0
# Episode 310, Reward: 156.0
# Episode 311, Reward: 35.0
# Episode 312, Reward: 16.0
# Episode 313, Reward: 69.0
# Episode 314, Reward: 38.0
# Episode 315, Reward: 58.0
# Episode 316, Reward: 30.0
# Episode 317, Reward: 59.0
# Episode 318, Reward: 93.0
# Episode 319, Reward: 89.0
# Episode 320, Reward: 43.0
# Episode 321, Reward: 83.0
# Episode 322, Reward: 87.0
# Episode 323, Reward: 122.0
# Episode 324, Reward: 145.0
# Episode 325, Reward: 45.0
# Episode 326, Reward: 172.0
# Episode 327, Reward: 129.0
# Episode 328, Reward: 109.0
# Episode 329, Reward: 145.0
# Episode 330, Reward: 40.0
# Episode 331, Reward: 122.0
# Episode 332, Reward: 35.0
# Episode 333, Reward: 69.0
# Episode 334, Reward: 92.0
# Episode 335, Reward: 201.0
# Episode 336, Reward: 78.0
# Episode 337, Reward: 217.0
# Episode 338, Reward: 69.0
# Episode 339, Reward: 76.0
# Episode 340, Reward: 223.0
# Episode 341, Reward: 40.0
# Episode 342, Reward: 68.0
# Episode 343, Reward: 274.0
# Episode 344, Reward: 81.0
# Episode 345, Reward: 48.0
# Episode 346, Reward: 18.0
# Episode 347, Reward: 40.0
# Episode 348, Reward: 22.0
# Episode 349, Reward: 25.0
# Episode 350, Reward: 19.0
# Episode 351, Reward: 20.0
# Episode 352, Reward: 17.0
# Episode 353, Reward: 17.0
# Episode 354, Reward: 15.0
# Episode 355, Reward: 14.0
# Episode 356, Reward: 16.0
# Episode 357, Reward: 19.0
# Episode 358, Reward: 12.0
# Episode 359, Reward: 14.0
# Episode 360, Reward: 18.0
# Episode 361, Reward: 23.0
# Episode 362, Reward: 47.0
# Episode 363, Reward: 123.0
# Episode 364, Reward: 63.0
# Episode 365, Reward: 140.0
# Episode 366, Reward: 27.0
# Episode 367, Reward: 155.0
# Episode 368, Reward: 157.0
# Episode 369, Reward: 140.0
# Episode 370, Reward: 122.0
# Episode 371, Reward: 250.0
# Episode 372, Reward: 80.0
# Episode 373, Reward: 119.0
# Episode 374, Reward: 12.0
# Episode 375, Reward: 168.0
# Episode 376, Reward: 37.0
# Episode 377, Reward: 55.0
# Episode 378, Reward: 458.0
# Episode 379, Reward: 135.0
# Episode 380, Reward: 108.0
# Episode 381, Reward: 238.0
# Episode 382, Reward: 36.0
# Episode 383, Reward: 46.0
# Episode 384, Reward: 23.0
# Episode 385, Reward: 21.0
# Episode 386, Reward: 179.0
# Episode 387, Reward: 226.0
# Episode 388, Reward: 141.0
# Episode 389, Reward: 282.0
# Episode 390, Reward: 149.0
# Episode 391, Reward: 213.0
# Episode 392, Reward: 54.0
# Episode 393, Reward: 125.0
# Episode 394, Reward: 179.0
# Episode 395, Reward: 207.0
# Episode 396, Reward: 238.0
# Episode 397, Reward: 125.0
# Episode 398, Reward: 34.0
# Episode 399, Reward: 22.0
# Episode 400, Reward: 121.0
# Episode 401, Reward: 37.0
# Episode 402, Reward: 32.0
# Episode 403, Reward: 19.0
# Episode 404, Reward: 90.0
# Episode 405, Reward: 109.0
# Episode 406, Reward: 111.0
# Episode 407, Reward: 134.0
# Episode 408, Reward: 91.0
# Episode 409, Reward: 101.0
# Episode 410, Reward: 30.0
# Episode 411, Reward: 87.0
# Episode 412, Reward: 95.0
# Episode 413, Reward: 117.0
# Episode 414, Reward: 25.0
# Episode 415, Reward: 147.0
# Episode 416, Reward: 153.0
# Episode 417, Reward: 205.0
# Episode 418, Reward: 184.0
# Episode 419, Reward: 152.0
# Episode 420, Reward: 135.0
# Episode 421, Reward: 118.0
# Episode 422, Reward: 93.0
# Episode 423, Reward: 105.0
# Episode 424, Reward: 136.0
# Episode 425, Reward: 198.0
# Episode 426, Reward: 28.0
# Episode 427, Reward: 150.0
# Episode 428, Reward: 22.0
# Episode 429, Reward: 155.0
# Episode 430, Reward: 352.0
# Episode 431, Reward: 139.0
# Episode 432, Reward: 179.0
# Episode 433, Reward: 183.0
# Episode 434, Reward: 142.0
# Episode 435, Reward: 118.0
# Episode 436, Reward: 214.0
# Episode 437, Reward: 168.0
# Episode 438, Reward: 120.0
# Episode 439, Reward: 37.0
# Episode 440, Reward: 31.0
# Episode 441, Reward: 19.0
# Episode 442, Reward: 122.0
# Episode 443, Reward: 187.0
# Episode 444, Reward: 167.0
# Episode 445, Reward: 171.0
# Episode 446, Reward: 132.0
# Episode 447, Reward: 98.0
# Episode 448, Reward: 117.0
# Episode 449, Reward: 155.0
# Episode 450, Reward: 149.0
# Episode 451, Reward: 150.0
# Episode 452, Reward: 139.0
# Episode 453, Reward: 194.0
# Episode 454, Reward: 219.0
# Episode 455, Reward: 212.0
# Episode 456, Reward: 67.0
# Episode 457, Reward: 127.0
# Episode 458, Reward: 62.0
# Episode 459, Reward: 55.0
# Episode 460, Reward: 198.0
# Episode 461, Reward: 149.0
# Episode 462, Reward: 152.0
# Episode 463, Reward: 147.0
# Episode 464, Reward: 114.0
# Episode 465, Reward: 115.0
# Episode 466, Reward: 121.0
# Episode 467, Reward: 171.0
# Episode 468, Reward: 181.0
# Episode 469, Reward: 280.0
# Episode 470, Reward: 70.0
# Episode 471, Reward: 163.0
# Episode 472, Reward: 28.0
# Episode 473, Reward: 113.0
# Episode 474, Reward: 23.0
# Episode 475, Reward: 147.0
# Episode 476, Reward: 28.0
# Episode 477, Reward: 181.0
# Episode 478, Reward: 165.0
# Episode 479, Reward: 135.0
# Episode 480, Reward: 119.0
# Episode 481, Reward: 119.0
# Episode 482, Reward: 117.0
# Episode 483, Reward: 108.0
# Episode 484, Reward: 134.0
# Episode 485, Reward: 30.0
# Episode 486, Reward: 205.0
# Episode 487, Reward: 187.0
# Episode 488, Reward: 153.0
# Episode 489, Reward: 33.0
# Episode 490, Reward: 38.0
# Episode 491, Reward: 250.0
# Episode 492, Reward: 166.0
# Episode 493, Reward: 122.0
# Episode 494, Reward: 125.0
# Episode 495, Reward: 123.0
# Episode 496, Reward: 112.0
# Episode 497, Reward: 121.0
# Episode 498, Reward: 142.0
# Episode 499, Reward: 166.0
# Episode 500, Reward: 135.0
# Episode 501, Reward: 132.0
# Episode 502, Reward: 145.0
# Episode 503, Reward: 157.0
# Episode 504, Reward: 175.0
# Episode 505, Reward: 286.0
# Episode 506, Reward: 160.0
# Episode 507, Reward: 61.0
# Episode 508, Reward: 197.0
# Episode 509, Reward: 118.0
# Episode 510, Reward: 18.0
# Episode 511, Reward: 21.0
# Episode 512, Reward: 14.0
# Episode 513, Reward: 15.0
# Episode 514, Reward: 17.0
# Episode 515, Reward: 19.0
# Episode 516, Reward: 19.0
# Episode 517, Reward: 23.0
# Episode 518, Reward: 31.0
# Episode 519, Reward: 112.0
# Episode 520, Reward: 144.0
# Episode 521, Reward: 219.0
# Episode 522, Reward: 198.0
# Episode 523, Reward: 118.0
# Episode 524, Reward: 124.0
# Episode 525, Reward: 144.0
# Episode 526, Reward: 102.0
# Episode 527, Reward: 104.0
# Episode 528, Reward: 116.0
# Episode 529, Reward: 128.0
# Episode 530, Reward: 125.0
# Episode 531, Reward: 161.0
# Episode 532, Reward: 106.0
# Episode 533, Reward: 93.0
# Episode 534, Reward: 111.0
# Episode 535, Reward: 106.0
# Episode 536, Reward: 120.0
# Episode 537, Reward: 99.0
# Episode 538, Reward: 97.0
# Episode 539, Reward: 16.0
# Episode 540, Reward: 113.0
# Episode 541, Reward: 103.0
# Episode 542, Reward: 82.0
# Episode 543, Reward: 48.0
# Episode 544, Reward: 88.0
# Episode 545, Reward: 36.0
# Episode 546, Reward: 117.0
# Episode 547, Reward: 88.0
# Episode 548, Reward: 84.0
# Episode 549, Reward: 50.0
# Episode 550, Reward: 229.0
# Episode 551, Reward: 231.0
# Episode 552, Reward: 126.0
# Episode 553, Reward: 128.0
# Episode 554, Reward: 155.0
# Episode 555, Reward: 244.0
# Episode 556, Reward: 341.0
# Episode 557, Reward: 159.0
# Episode 558, Reward: 323.0
# Episode 559, Reward: 203.0
# Episode 560, Reward: 235.0
# Episode 561, Reward: 230.0
# Episode 562, Reward: 134.0
# Episode 563, Reward: 117.0
# Episode 564, Reward: 124.0
# Episode 565, Reward: 113.0
# Episode 566, Reward: 158.0
# Episode 567, Reward: 203.0
# Episode 568, Reward: 190.0
# Episode 569, Reward: 230.0
# Episode 570, Reward: 192.0
# Episode 571, Reward: 222.0
# Episode 572, Reward: 110.0
# Episode 573, Reward: 17.0
# Episode 574, Reward: 19.0
# Episode 575, Reward: 20.0
# Episode 576, Reward: 18.0
# Episode 577, Reward: 16.0
# Episode 578, Reward: 15.0
# Episode 579, Reward: 11.0
# Episode 580, Reward: 16.0
# Episode 581, Reward: 14.0
# Episode 582, Reward: 16.0
# Episode 583, Reward: 17.0
# Episode 584, Reward: 26.0
# Episode 585, Reward: 110.0
# Episode 586, Reward: 24.0
# Episode 587, Reward: 22.0
# Episode 588, Reward: 118.0
# Episode 589, Reward: 156.0
# Episode 590, Reward: 177.0
# Episode 591, Reward: 136.0
# Episode 592, Reward: 157.0
# Episode 593, Reward: 184.0
# Episode 594, Reward: 121.0
# Episode 595, Reward: 114.0
# Episode 596, Reward: 108.0
# Episode 597, Reward: 31.0
# Episode 598, Reward: 29.0
# Episode 599, Reward: 112.0
# Episode 600, Reward: 102.0
# Episode 601, Reward: 97.0
# Episode 602, Reward: 28.0
# Episode 603, Reward: 140.0
# Episode 604, Reward: 156.0
# Episode 605, Reward: 116.0
# Episode 606, Reward: 88.0
# Episode 607, Reward: 110.0
# Episode 608, Reward: 86.0
# Episode 609, Reward: 104.0
# Episode 610, Reward: 82.0
# Episode 611, Reward: 121.0
# Episode 612, Reward: 178.0
# Episode 613, Reward: 158.0
# Episode 614, Reward: 114.0
# Episode 615, Reward: 32.0
# Episode 616, Reward: 124.0
# Episode 617, Reward: 125.0
# Episode 618, Reward: 108.0
# Episode 619, Reward: 116.0
# Episode 620, Reward: 134.0
# Episode 621, Reward: 134.0
# Episode 622, Reward: 148.0
# Episode 623, Reward: 119.0
# Episode 624, Reward: 108.0
# Episode 625, Reward: 124.0
# Episode 626, Reward: 32.0
# Episode 627, Reward: 231.0
# Episode 628, Reward: 156.0
# Episode 629, Reward: 198.0
# Episode 630, Reward: 139.0
# Episode 631, Reward: 111.0
# Episode 632, Reward: 114.0
# Episode 633, Reward: 103.0
# Episode 634, Reward: 106.0
# Episode 635, Reward: 106.0
# Episode 636, Reward: 109.0
# Episode 637, Reward: 25.0
# Episode 638, Reward: 179.0
# Episode 639, Reward: 326.0
# Episode 640, Reward: 459.0
# Episode 641, Reward: 107.0
# Episode 642, Reward: 96.0
# Episode 643, Reward: 24.0
# Episode 644, Reward: 16.0
# Episode 645, Reward: 15.0
# Episode 646, Reward: 30.0
# Episode 647, Reward: 112.0
# Episode 648, Reward: 142.0
# Episode 649, Reward: 149.0
# Episode 650, Reward: 156.0
# Episode 651, Reward: 153.0
# Episode 652, Reward: 124.0
# Episode 653, Reward: 150.0
# Episode 654, Reward: 131.0
# Episode 655, Reward: 136.0
# Episode 656, Reward: 144.0
# Episode 657, Reward: 158.0
# Episode 658, Reward: 177.0
# Episode 659, Reward: 150.0
# Episode 660, Reward: 155.0
# Episode 661, Reward: 132.0
# Episode 662, Reward: 136.0
# Episode 663, Reward: 139.0
# Episode 664, Reward: 123.0
# Episode 665, Reward: 128.0
# Episode 666, Reward: 126.0
# Episode 667, Reward: 131.0
# Episode 668, Reward: 107.0
# Episode 669, Reward: 114.0
# Episode 670, Reward: 105.0
# Episode 671, Reward: 18.0
# Episode 672, Reward: 100.0
# Episode 673, Reward: 118.0
# Episode 674, Reward: 128.0
# Episode 675, Reward: 176.0
# Episode 676, Reward: 153.0
# Episode 677, Reward: 160.0
# Episode 678, Reward: 169.0
# Episode 679, Reward: 238.0
# Episode 680, Reward: 210.0
# Episode 681, Reward: 187.0
# Episode 682, Reward: 152.0
# Episode 683, Reward: 140.0
# Episode 684, Reward: 155.0
# Episode 685, Reward: 322.0
# Episode 686, Reward: 154.0
# Episode 687, Reward: 244.0
# Episode 688, Reward: 229.0
# Episode 689, Reward: 173.0
# Episode 690, Reward: 120.0
# Episode 691, Reward: 126.0
# Episode 692, Reward: 144.0
# Episode 693, Reward: 150.0
# Episode 694, Reward: 148.0
# Episode 695, Reward: 159.0
# Episode 696, Reward: 168.0
# Episode 697, Reward: 172.0
# Episode 698, Reward: 162.0
# Episode 699, Reward: 158.0
# Episode 700, Reward: 174.0
# Episode 701, Reward: 150.0
# Episode 702, Reward: 161.0
# Episode 703, Reward: 139.0
# Episode 704, Reward: 57.0
# Episode 705, Reward: 165.0
# Episode 706, Reward: 357.0
# Episode 707, Reward: 159.0
# Episode 708, Reward: 20.0
# Episode 709, Reward: 11.0
# Episode 710, Reward: 146.0
# Episode 711, Reward: 28.0
# Episode 712, Reward: 261.0
# Episode 713, Reward: 110.0
# Episode 714, Reward: 114.0
# Episode 715, Reward: 135.0
# Episode 716, Reward: 141.0
# Episode 717, Reward: 129.0
# Episode 718, Reward: 128.0
# Episode 719, Reward: 160.0
# Episode 720, Reward: 116.0
# Episode 721, Reward: 143.0
# Episode 722, Reward: 136.0
# Episode 723, Reward: 23.0
# Episode 724, Reward: 129.0
# Episode 725, Reward: 118.0
# Episode 726, Reward: 164.0
# Episode 727, Reward: 126.0
# Episode 728, Reward: 206.0
# Episode 729, Reward: 171.0
# Episode 730, Reward: 151.0
# Episode 731, Reward: 150.0
# Episode 732, Reward: 182.0
# Episode 733, Reward: 254.0
# Episode 734, Reward: 251.0
# Episode 735, Reward: 142.0
# Episode 736, Reward: 163.0
# Episode 737, Reward: 164.0
# Episode 738, Reward: 147.0
# Episode 739, Reward: 152.0
# Episode 740, Reward: 188.0
# Episode 741, Reward: 171.0
# Episode 742, Reward: 130.0
# Episode 743, Reward: 137.0
# Episode 744, Reward: 165.0
# Episode 745, Reward: 194.0
# Episode 746, Reward: 154.0
# Episode 747, Reward: 148.0
# Episode 748, Reward: 196.0
# Episode 749, Reward: 180.0
# Episode 750, Reward: 155.0
# Episode 751, Reward: 164.0
# Episode 752, Reward: 159.0
# Episode 753, Reward: 154.0
# Episode 754, Reward: 166.0
# Episode 755, Reward: 196.0
# Episode 756, Reward: 213.0
# Episode 757, Reward: 158.0
# Episode 758, Reward: 162.0
# Episode 759, Reward: 161.0
# Episode 760, Reward: 145.0
# Episode 761, Reward: 181.0
# Episode 762, Reward: 142.0
# Episode 763, Reward: 122.0
# Episode 764, Reward: 24.0
# Episode 765, Reward: 284.0
# Episode 766, Reward: 138.0
# Episode 767, Reward: 19.0
# Episode 768, Reward: 112.0
# Episode 769, Reward: 234.0
# Episode 770, Reward: 155.0
# Episode 771, Reward: 121.0
# Episode 772, Reward: 19.0
# Episode 773, Reward: 14.0
# Episode 774, Reward: 13.0
# Episode 775, Reward: 16.0
# Episode 776, Reward: 16.0
# Episode 777, Reward: 18.0
# Episode 778, Reward: 115.0
# Episode 779, Reward: 140.0
# Episode 780, Reward: 158.0
# Episode 781, Reward: 142.0
# Episode 782, Reward: 148.0
# Episode 783, Reward: 143.0
# Episode 784, Reward: 167.0
# Episode 785, Reward: 137.0
# Episode 786, Reward: 129.0
# Episode 787, Reward: 175.0
# Episode 788, Reward: 156.0
# Episode 789, Reward: 148.0
# Episode 790, Reward: 116.0
# Episode 791, Reward: 121.0
# Episode 792, Reward: 137.0
# Episode 793, Reward: 163.0
# Episode 794, Reward: 154.0
# Episode 795, Reward: 170.0
# Episode 796, Reward: 157.0
# Episode 797, Reward: 172.0
# Episode 798, Reward: 394.0
# Episode 799, Reward: 274.0
# Episode 800, Reward: 177.0
# Episode 801, Reward: 156.0
# Episode 802, Reward: 212.0
# Episode 803, Reward: 226.0
# Episode 804, Reward: 246.0
# Episode 805, Reward: 257.0
# Episode 806, Reward: 188.0
# Episode 807, Reward: 214.0
# Episode 808, Reward: 215.0
# Episode 809, Reward: 206.0
# Episode 810, Reward: 193.0
# Episode 811, Reward: 165.0
# Episode 812, Reward: 204.0
# Episode 813, Reward: 177.0
# Episode 814, Reward: 206.0
# Episode 815, Reward: 298.0
# Episode 816, Reward: 500.0
# Episode 817, Reward: 229.0
# Episode 818, Reward: 357.0
# Episode 819, Reward: 356.0
# Episode 820, Reward: 500.0
# Episode 821, Reward: 134.0
# Episode 822, Reward: 126.0
# Episode 823, Reward: 500.0
# Episode 824, Reward: 500.0
# Episode 825, Reward: 500.0
# Episode 826, Reward: 500.0
# Episode 827, Reward: 152.0
# Episode 828, Reward: 171.0
# Episode 829, Reward: 278.0
# Episode 830, Reward: 28.0
# Episode 831, Reward: 165.0
# Episode 832, Reward: 127.0
# Episode 833, Reward: 16.0
# Episode 834, Reward: 296.0
# Episode 835, Reward: 500.0
# Episode 836, Reward: 500.0
# Episode 837, Reward: 298.0
# Episode 838, Reward: 294.0
# Episode 839, Reward: 438.0
# Episode 840, Reward: 500.0
# Episode 841, Reward: 500.0
# Episode 842, Reward: 500.0
# Episode 843, Reward: 500.0
# Episode 844, Reward: 500.0
# Episode 845, Reward: 275.0
# Episode 846, Reward: 22.0
# Episode 847, Reward: 21.0
# Episode 848, Reward: 17.0
# Episode 849, Reward: 17.0
# Episode 850, Reward: 14.0
# Episode 851, Reward: 14.0
# Episode 852, Reward: 15.0
# Episode 853, Reward: 18.0
# Episode 854, Reward: 19.0
# Episode 855, Reward: 24.0
# Episode 856, Reward: 500.0
# Episode 857, Reward: 500.0
# Episode 858, Reward: 500.0
# Episode 859, Reward: 167.0
# Episode 860, Reward: 123.0
# Episode 861, Reward: 109.0
# Episode 862, Reward: 29.0
# Episode 863, Reward: 17.0
# Episode 864, Reward: 101.0
# Episode 865, Reward: 175.0
# Episode 866, Reward: 174.0
# Episode 867, Reward: 172.0
# Episode 868, Reward: 144.0
# Episode 869, Reward: 175.0
# Episode 870, Reward: 142.0
# Episode 871, Reward: 144.0
# Episode 872, Reward: 124.0
# Episode 873, Reward: 117.0
# Episode 874, Reward: 120.0
# Episode 875, Reward: 119.0
# Episode 876, Reward: 121.0
# Episode 877, Reward: 110.0
# Episode 878, Reward: 117.0
# Episode 879, Reward: 125.0
# Episode 880, Reward: 126.0
# Episode 881, Reward: 98.0
# Episode 882, Reward: 108.0
# Episode 883, Reward: 105.0
# Episode 884, Reward: 93.0
# Episode 885, Reward: 119.0
# Episode 886, Reward: 117.0
# Episode 887, Reward: 114.0
# Episode 888, Reward: 82.0
# Episode 889, Reward: 89.0
# Episode 890, Reward: 85.0
# Episode 891, Reward: 92.0
# Episode 892, Reward: 98.0
# Episode 893, Reward: 83.0
# Episode 894, Reward: 84.0
# Episode 895, Reward: 89.0
# Episode 896, Reward: 93.0
# Episode 897, Reward: 85.0
# Episode 898, Reward: 41.0
# Episode 899, Reward: 54.0
# Episode 900, Reward: 91.0
# Episode 901, Reward: 100.0
# Episode 902, Reward: 105.0
# Episode 903, Reward: 98.0
# Episode 904, Reward: 85.0
# Episode 905, Reward: 103.0
# Episode 906, Reward: 111.0
# Episode 907, Reward: 84.0
# Episode 908, Reward: 108.0
# Episode 909, Reward: 124.0
# Episode 910, Reward: 107.0
# Episode 911, Reward: 88.0
# Episode 912, Reward: 75.0
# Episode 913, Reward: 66.0
# Episode 914, Reward: 73.0
# Episode 915, Reward: 38.0
# Episode 916, Reward: 104.0
# Episode 917, Reward: 104.0
# Episode 918, Reward: 70.0
# Episode 919, Reward: 101.0
# Episode 920, Reward: 124.0
# Episode 921, Reward: 90.0
# Episode 922, Reward: 144.0
# Episode 923, Reward: 131.0
# Episode 924, Reward: 158.0
# Episode 925, Reward: 136.0
# Episode 926, Reward: 142.0
# Episode 927, Reward: 102.0
# Episode 928, Reward: 133.0
# Episode 929, Reward: 110.0
# Episode 930, Reward: 79.0
# Episode 931, Reward: 92.0
# Episode 932, Reward: 153.0
# Episode 933, Reward: 114.0
# Episode 934, Reward: 99.0
# Episode 935, Reward: 118.0
# Episode 936, Reward: 113.0
# Episode 937, Reward: 130.0
# Episode 938, Reward: 96.0
# Episode 939, Reward: 103.0
# Episode 940, Reward: 93.0
# Episode 941, Reward: 99.0
# Episode 942, Reward: 99.0
# Episode 943, Reward: 105.0
# Episode 944, Reward: 153.0
# Episode 945, Reward: 127.0
# Episode 946, Reward: 126.0
# Episode 947, Reward: 117.0
# Episode 948, Reward: 157.0
# Episode 949, Reward: 126.0
# Episode 950, Reward: 179.0
# Episode 951, Reward: 168.0
# Episode 952, Reward: 161.0
# Episode 953, Reward: 186.0
# Episode 954, Reward: 256.0
# Episode 955, Reward: 207.0
# Episode 956, Reward: 236.0
# Episode 957, Reward: 500.0
# Episode 958, Reward: 210.0
# Episode 959, Reward: 153.0
# Episode 960, Reward: 206.0
# Episode 961, Reward: 500.0
# Episode 962, Reward: 500.0
# Episode 963, Reward: 328.0
# Episode 964, Reward: 21.0
# Episode 965, Reward: 16.0
# Episode 966, Reward: 16.0
# Episode 967, Reward: 11.0
# Episode 968, Reward: 14.0
# Episode 969, Reward: 14.0
# Episode 970, Reward: 14.0
# Episode 971, Reward: 12.0
# Episode 972, Reward: 18.0
# Episode 973, Reward: 14.0
# Episode 974, Reward: 13.0
# Episode 975, Reward: 14.0
# Episode 976, Reward: 11.0
# Episode 977, Reward: 13.0
# Episode 978, Reward: 18.0
# Episode 979, Reward: 17.0
# Episode 980, Reward: 14.0
# Episode 981, Reward: 16.0
# Episode 982, Reward: 15.0
# Episode 983, Reward: 15.0
# Episode 984, Reward: 18.0
# Episode 985, Reward: 19.0
# Episode 986, Reward: 19.0
# Episode 987, Reward: 29.0
# Episode 988, Reward: 27.0
# Episode 989, Reward: 33.0
# Episode 990, Reward: 100.0
# Episode 991, Reward: 169.0
# Episode 992, Reward: 139.0
# Episode 993, Reward: 195.0
# Episode 994, Reward: 332.0
# Episode 995, Reward: 296.0
# Episode 996, Reward: 458.0
# Episode 997, Reward: 128.0
# Episode 998, Reward: 118.0
# Episode 999, Reward: 117.0

# %% [markdown]
# ---
#
# ### **Implementação do A2C com PyTorch**
#
# Este exemplo segue os componentes principais do A2C:
#
# 1. **Ator-Crítico**: Rede neural que prediz a política ($ \pi(a|s) $) e o valor ($ V(s) $).
# 2. **Cálculo da Função Advantage**: Para reduzir a variância.
# 3. **Atualização dos Pesos**: Baseada no gradiente Advantage.
#
# ---
#
# ### **Como Funciona o Código**
# 1. **Rede Ator-Crítico**:
#    - Camada compartilhada para aprender representações do estado.
#    - Duas saídas:
#      - A política (probabilidade de ações).
#      - O valor esperado ($ V(s) $).
#
# 2. **Função Advantage**:
#    - Calculada como $ A(s, a) = G_t - V(s) $, onde $ G_t $ é o retorno acumulado com desconto.
#
# 3. **Atualização dos Pesos**:
#    - **Loss do Ator**: Maximiza o log da probabilidade ponderada pela vantagem.
#    - **Loss do Crítico**: Minimiza a diferença quadrada entre o retorno e o valor estimado.
#
# 4. **Exploração Paralela** (não implementado neste exemplo):
#    - A2C pode ser adaptado para rodar em múltiplos ambientes paralelos, mas este exemplo utiliza apenas um ambiente para simplificar.
#
# ---
#
# ### **Extensões**
# - Implementar **múltiplos ambientes** para maior eficiência (paralelismo no A2C).
# - Experimentar com **A3C** usando `torch.multiprocessing` para execuções assíncronas.
# - Adicionar regularização de entropia para melhorar a exploração.

# %% [markdown]
# ##Explicação do código
#
# ### **Importações e Configurações**
# ```python
# import gymnasium as gym
# import torch
# import torch.nn as nn
# import torch.optim as optim
# import numpy as np
# ```
# 1. **`gymnasium`**: Biblioteca usada para criar ambientes de aprendizado por reforço. Substitui o antigo `gym`.
# 2. **`torch` e `torch.nn`**: Usados para construir e treinar a rede neural.
# 3. **`torch.optim`**: Contém otimizadores, como Adam, para atualizar os pesos da rede neural.
# 4. **`numpy`**: Biblioteca para manipulação de arrays, usada para conversão e processamento de dados numéricos.
#
# ```python
# ENV_NAME = "CartPole-v1"
# GAMMA = 0.99
# LR = 1e-3
# N_STEPS = 5
# MAX_EPISODES = 1000
# ```
# 5. **`ENV_NAME`**: Nome do ambiente. Neste caso, é o clássico problema do pêndulo invertido (CartPole).
# 6. **`GAMMA`**: Taxa de desconto (discount factor), que controla a importância das recompensas futuras.
# 7. **`LR`**: Taxa de aprendizado para o otimizador.
# 8. **`N_STEPS`**: Número de passos para atualizar a política no estilo A2C.
# 9. **`MAX_EPISODES`**: Quantidade máxima de episódios de treinamento.
#
# ---
#
# ### **Definição da Rede Neural Actor-Critic**
# ```python
# class ActorCritic(nn.Module):
#     def __init__(self, input_dim, action_dim):
#         super(ActorCritic, self).__init__()
#         self.shared_layers = nn.Sequential(
#             nn.Linear(input_dim, 128),
#             nn.ReLU(),
#         )
#         self.actor = nn.Sequential(
#             nn.Linear(128, action_dim),
#             nn.Softmax(dim=-1)
#         )
#         self.critic = nn.Linear(128, 1)
#
#     def forward(self, state):
#         shared = self.shared_layers(state)
#         policy = self.actor(shared)
#         value = self.critic(shared)
#         return policy, value
# ```
#
# 1. **`ActorCritic`**: Classe que implementa a rede neural com duas cabeças:
#    - **Ator (actor)**: Responsável por calcular a política (distribuição de probabilidades das ações).
#    - **Crítico (critic)**: Responsável por calcular o valor esperado do estado (função de valor).
# 2. **`__init__`**:
#    - **`input_dim`**: Dimensão da entrada (quantidade de variáveis no estado do ambiente).
#    - **`action_dim`**: Dimensão da saída (número de ações possíveis).
#    - **`shared_layers`**: Camadas compartilhadas entre o ator e o crítico, com 128 neurônios e ativação ReLU.
#    - **`actor`**: Cabeça do ator, que aplica Softmax para obter uma distribuição de probabilidades para as ações.
#    - **`critic`**: Cabeça do crítico, que retorna um único valor representando o valor esperado do estado.
# 3. **`forward`**:
#    - Processa o estado de entrada pelas camadas compartilhadas e calcula separadamente a política (`policy`) e o valor (`value`).
#
# ---
#
# ### **Agente A2C**
# ```python
# class A2CAgent:
#     def __init__(self, env):
#         self.env = env
#         self.state_dim = env.observation_space.shape[0]
#         self.action_dim = env.action_space.n
#         self.model = ActorCritic(self.state_dim, self.action_dim)
#         self.optimizer = optim.Adam(self.model.parameters(), lr=LR)
# ```
# 1. **`__init__`**:
#    - Inicializa o ambiente e extrai as dimensões do espaço de observação (`state_dim`) e do espaço de ações (`action_dim`).
#    - Cria o modelo `ActorCritic` e o otimizador Adam para treinar os pesos da rede.
#
# ```python
# def select_action(self, state):
#     state = torch.FloatTensor(state).unsqueeze(0)
#     policy, _ = self.model(state)
#     action = torch.multinomial(policy, num_samples=1).item()
#     return action
# ```
# 2. **`select_action`**:
#    - Converte o estado para um tensor `FloatTensor`.
#    - Passa o estado pela rede para obter a política (`policy`).
#    - Seleciona uma ação aleatória com base na política (usando `torch.multinomial`).
#
# ```python
# def compute_advantage(self, rewards, values, next_value, dones):
#     returns = []
#     R = next_value
#     for step in reversed(range(len(rewards))):
#         R = rewards[step] + GAMMA * R * (1 - dones[step])
#         returns.insert(0, R)
#     returns = torch.tensor(returns)
#     advantage = returns - values
#     return returns, advantage
# ```
# 3. **`compute_advantage`**:
#    - Calcula o retorno descontado (G) e a vantagem (advantage).
#    - A vantagem é a diferença entre o retorno esperado e o valor estimado.
#
# ```python
# def train(self, trajectory):
#     states, actions, rewards, dones, next_state = trajectory
#     states = torch.FloatTensor(states)
#     actions = torch.LongTensor(actions)
#     rewards = torch.FloatTensor(rewards)
#     dones = torch.FloatTensor(dones)
#     next_state = torch.FloatTensor(next_state).unsqueeze(0)
#
#     _, next_value = self.model(next_state)
#     policy, values = self.model(states)
#     values = values.squeeze()
#     returns, advantage = self.compute_advantage(rewards, values, next_value.item(), dones)
#
#     log_probs = torch.log(policy.gather(1, actions.unsqueeze(1)).squeeze())
#     actor_loss = -(log_probs * advantage.detach()).mean()
#     critic_loss = advantage.pow(2).mean()
#     loss = actor_loss + critic_loss
#
#     self.optimizer.zero_grad()
#     loss.backward()
#     self.optimizer.step()
# ```
# 4. **`train`**:
#    - Extrai os dados da trajetória.
#    - Calcula a política, valores e vantagem.
#    - Define as perdas:
#      - **`actor_loss`**: Mede o desempenho da política com base na vantagem.
#      - **`critic_loss`**: Penaliza estimativas incorretas de valores.
#    - Realiza o backpropagation e atualiza os pesos.
#
# ---
#
# ### **Loop Principal**
# ```python
# def train_a2c():
#     env = gym.make(ENV_NAME)
#     agent = A2CAgent(env)
#
#     for episode in range(MAX_EPISODES):
#         state, _ = env.reset()
#         trajectory = {"states": [], "actions": [], "rewards": [], "dones": []}
#         episode_reward = 0
#
#         for t in range(1, 10000):
#             action = agent.select_action(state)
#             next_state, reward, done, truncated, _ = env.step(action)
#
#             state = np.array(state, dtype=np.float32).tolist()
#             next_state = np.array(next_state, dtype=np.float32).tolist()
#
#             trajectory["states"].append(state)
#             trajectory["actions"].append(action)
#             trajectory["rewards"].append(reward)
#             trajectory["dones"].append(done or truncated)
#             state = next_state
#             episode_reward += reward
#
#             if len(trajectory["rewards"]) == N_STEPS or done or truncated:
#                 trajectory["next_state"] = state
#                 agent.train((
#                     trajectory["states"],
#                     trajectory["actions"],
#                     trajectory["rewards"],
#                     trajectory["dones"],
#                     trajectory["next_state"]
#                 ))
#                 trajectory = {"states": [], "actions": [], "rewards": [], "dones": []}
#
#             if done or truncated:
#                 print(f"Episode {episode}, Reward: {episode_reward}")
#                 break
#
#     env.close()
# ```
#
# 1. **`train_a2c`**:
#    - Cria o ambiente e inicializa o agente.
#    - Para cada episódio, coleta trajetórias e atualiza o modelo a cada `N_STEPS`.
#    - Armazena o estado, ação, recompensa e se o episódio terminou.
#    - Calcula e aplica gradientes para treinar o modelo.
#
# ---
#
# ### **Execução**
# ```python
# if __name__ == "__main__":
#     train_a2c()
# ```
# Executa o treinamento.
#
# ---

# %% [markdown]
# O **A3C (Asynchronous Advantage Actor-Critic)** é uma extensão do A2C que permite treinar múltiplos agentes (ou "trabalhadores") de forma assíncrona em diferentes threads ou processos. Ele melhora a eficiência do treinamento e reduz a correlação entre as trajetórias coletadas pelos trabalhadores.
#
# Abaixo, apresento uma implementação simplificada do A3C em Python usando o **PyTorch** e o **Gymnasium**, utilizando o módulo `multiprocessing` para lidar com os trabalhadores.
#
# ---
#
# ### **Código Completo do A3C**

# %%
import gymnasium as gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.multiprocessing as mp
import numpy as np
from collections import deque

# Configurações globais
ENV_NAME = "CartPole-v1"
GAMMA = 0.99
LR = 1e-3
N_STEPS = 5
MAX_EPISODES = 1000
NUM_WORKERS = 4  # Número de threads/trabalhadores

# Rede Actor-Critic compartilhada entre os trabalhadores
class ActorCritic(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.shared_layers = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
        )
        self.actor = nn.Sequential(
            nn.Linear(128, action_dim),
            nn.Softmax(dim=-1)
        )
        self.critic = nn.Linear(128, 1)

    def forward(self, state):
        shared = self.shared_layers(state)
        policy = self.actor(shared)
        value = self.critic(shared)
        return policy, value

# Função auxiliar para calcular vantagem e retorno
def compute_advantage(rewards, values, next_value, dones):
    returns = []
    R = next_value
    for step in reversed(range(len(rewards))):
        R = rewards[step] + GAMMA * R * (1 - dones[step])
        returns.insert(0, R)
    returns = torch.tensor(returns)
    advantage = returns - values
    return returns, advantage

# Função principal de cada trabalhador
def worker(worker_id, global_model, optimizer, global_episode, results_queue):
    env = gym.make(ENV_NAME)
    local_model = ActorCritic(env.observation_space.shape[0], env.action_space.n)
    local_model.load_state_dict(global_model.state_dict())

    while global_episode.value < MAX_EPISODES:
        state, _ = env.reset()
        trajectory = {"states": [], "actions": [], "rewards": [], "dones": []}
        episode_reward = 0

        for t in range(1, 10000):
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            policy, value = local_model(state_tensor)
            action = torch.multinomial(policy, 1).item()

            next_state, reward, done, truncated, _ = env.step(action)
            episode_reward += reward

            # Armazenar trajetória
            # trajectory["states"].append(state)
            # trajectory["actions"].append(action)
            # trajectory["rewards"].append(reward)
            trajectory["states"].append(np.array(state, dtype=np.float32))
            trajectory["actions"].append(np.array(action, dtype=np.float32))
            trajectory["rewards"].append(np.array(reward, dtype=np.float32))
            trajectory["dones"].append(done or truncated)

            state = next_state
            if len(trajectory["rewards"]) == N_STEPS or done or truncated:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                _, next_value = local_model(next_state_tensor)
                next_value = next_value.item() if not (done or truncated) else 0.0

                # Prepara tensores
                states = torch.FloatTensor(np.array(trajectory["states"]))
                actions = torch.LongTensor(np.array(trajectory["actions"]))
                rewards = torch.FloatTensor(np.array(trajectory["rewards"]))
                dones = torch.FloatTensor(trajectory["dones"])

                # Calcula vantagem e retornos
                policy, values = local_model(states)
                values = values.squeeze()
                returns, advantage = compute_advantage(rewards, values, next_value, dones)

                # Calcula perdas
                log_probs = torch.log(policy.gather(1, actions.unsqueeze(1)).squeeze())
                actor_loss = -(log_probs * advantage.detach()).mean()
                critic_loss = advantage.pow(2).mean()
                loss = actor_loss + critic_loss

                # Atualiza o modelo global
                optimizer.zero_grad()
                loss.backward()
                for global_param, local_param in zip(global_model.parameters(), local_model.parameters()):
                    global_param.grad = local_param.grad
                optimizer.step()

                # Atualiza o modelo local
                local_model.load_state_dict(global_model.state_dict())
                trajectory = {"states": [], "actions": [], "rewards": [], "dones": []}

            if done or truncated:
                with global_episode.get_lock():
                    global_episode.value += 1
                results_queue.put(episode_reward)
                print(f"Worker {worker_id}, Episode {global_episode.value}, Reward: {episode_reward}")
                break

    env.close()

# Função principal para treinar o A3C
def train_a3c():
    env = gym.make(ENV_NAME)
    global_model = ActorCritic(env.observation_space.shape[0], env.action_space.n)
    global_model.share_memory()  # Compartilhar modelo entre processos
    optimizer = optim.Adam(global_model.parameters(), lr=LR)
    global_episode = mp.Value("i", 0)
    results_queue = mp.Queue()

    workers = []
    for worker_id in range(NUM_WORKERS):
        worker_process = mp.Process(
            target=worker,
            args=(worker_id, global_model, optimizer, global_episode, results_queue)
        )
        workers.append(worker_process)

    for worker_process in workers:
        worker_process.start()

    for worker_process in workers:
        worker_process.join()

    # Coleta resultados
    results = []
    while not results_queue.empty():
        results.append(results_queue.get())

    print("Treinamento concluído!")
    print(f"Média de recompensa por episódio: {np.mean(results):.2f}")

if __name__ == "__main__":
    train_a3c()
# Out:
# Worker 0, Episode 1, Reward: 30.0
# Worker 1, Episode 2, Reward: 25.0
# Worker 2, Episode 3, Reward: 26.0
# Worker 0, Episode 4, Reward: 30.0
# Worker 1, Episode 5, Reward: 24.0
# Worker 3, Episode 6, Reward: 29.0
# Worker 0, Episode 7, Reward: 20.0
# Worker 2, Episode 9, Reward: 36.0Worker 3, Episode 9, Reward: 10.0
#
# Worker 1, Episode 10, Reward: 16.0
# Worker 0, Episode 11, Reward: 19.0Worker 2, Episode 12, Reward: 11.0
#
# Worker 1, Episode 13, Reward: 9.0
# Worker 3, Episode 14, Reward: 21.0
# Worker 2, Episode 15, Reward: 12.0Worker 1, Episode 16, Reward: 9.0
#
# Worker 0, Episode 17, Reward: 16.0
# Worker 2, Episode 18, Reward: 9.0Worker 3, Episode 19, Reward: 9.0
#
# Worker 1, Episode 21, Reward: 9.0Worker 0, Episode 21, Reward: 9.0
#
# Worker 3, Episode 22, Reward: 11.0
# Worker 2, Episode 23, Reward: 11.0Worker 0, Episode 24, Reward: 10.0
# Worker 1, Episode 25, Reward: 11.0
#
# Worker 3, Episode 26, Reward: 10.0
# Worker 2, Episode 27, Reward: 9.0Worker 1, Episode 29, Reward: 10.0
# Worker 0, Episode 29, Reward: 10.0
#
# Worker 3, Episode 30, Reward: 9.0Worker 1, Episode 31, Reward: 9.0
#
# Worker 0, Episode 33, Reward: 9.0Worker 2, Episode 33, Reward: 9.0
#
# Worker 3, Episode 34, Reward: 9.0Worker 2, Episode 35, Reward: 10.0
#
# Worker 1, Episode 36, Reward: 10.0
# Worker 0, Episode 37, Reward: 9.0Worker 3, Episode 38, Reward: 9.0
#
# Worker 2, Episode 39, Reward: 10.0Worker 1, Episode 40, Reward: 10.0
# Worker 0, Episode 41, Reward: 9.0
#
# Worker 1, Episode 44, Reward: 8.0Worker 0, Episode 42, Reward: 10.0
# Worker 3, Episode 43, Reward: 9.0
# Worker 2, Episode 45, Reward: 9.0
# Worker 1, Episode 46, Reward: 10.0
#
# Worker 0, Episode 47, Reward: 10.0Worker 1, Episode 50, Reward: 8.0Worker 3, Episode 48, Reward: 9.0
# Worker 2, Episode 50, Reward: 10.0
#
#
# Worker 2, Episode 53, Reward: 10.0Worker 1, Episode 51, Reward: 10.0Worker 0, Episode 53, Reward: 9.0
# Worker 3, Episode 54, Reward: 10.0
#
#
# Worker 2, Episode 55, Reward: 8.0Worker 3, Episode 56, Reward: 9.0
# Worker 1, Episode 58, Reward: 11.0
# Worker 0, Episode 57, Reward: 9.0
#
# Worker 2, Episode 59, Reward: 9.0Worker 3, Episode 60, Reward: 8.0Worker 1, Episode 61, Reward: 9.0Worker 0, Episode 62, Reward: 10.0
#
#
#
# Worker 2, Episode 63, Reward: 10.0
# Worker 0, Episode 65, Reward: 9.0Worker 3, Episode 64, Reward: 10.0
# Worker 2, Episode 67, Reward: 9.0
#
# Worker 1, Episode 66, Reward: 9.0
# Worker 3, Episode 68, Reward: 10.0
# Worker 2, Episode 70, Reward: 10.0
# Worker 0, Episode 70, Reward: 9.0
# Worker 1, Episode 71, Reward: 9.0
# Worker 2, Episode 72, Reward: 10.0Worker 3, Episode 73, Reward: 9.0Worker 0, Episode 74, Reward: 10.0
#
#
# Worker 1, Episode 75, Reward: 9.0Worker 3, Episode 77, Reward: 8.0Worker 0, Episode 77, Reward: 9.0Worker 2, Episode 78, Reward: 8.0
#
#
#
# Worker 3, Episode 80, Reward: 9.0
# Worker 3, Episode 81, Reward: 10.0Worker 2, Episode 79, Reward: 9.0
#
# Worker 0, Episode 83, Reward: 9.0Worker 1, Episode 83, Reward: 10.0
#
# Worker 3, Episode 84, Reward: 10.0Worker 2, Episode 85, Reward: 9.0
#
# Worker 0, Episode 86, Reward: 10.0
# Worker 2, Episode 87, Reward: 8.0Worker 3, Episode 88, Reward: 9.0
# Worker 1, Episode 89, Reward: 8.0
#
# Worker 0, Episode 90, Reward: 9.0
# Worker 3, Episode 92, Reward: 10.0
# Worker 2, Episode 91, Reward: 10.0
# Worker 0, Episode 93, Reward: 8.0Worker 1, Episode 94, Reward: 8.0
#
# Worker 2, Episode 95, Reward: 8.0
# Worker 3, Episode 96, Reward: 9.0
# Worker 0, Episode 98, Reward: 10.0
# Worker 1, Episode 98, Reward: 10.0
# Worker 2, Episode 99, Reward: 9.0
# Worker 3, Episode 100, Reward: 8.0
# Worker 0, Episode 101, Reward: 9.0
# Worker 1, Episode 102, Reward: 8.0Worker 2, Episode 103, Reward: 8.0
#
# Worker 3, Episode 104, Reward: 9.0
# Worker 0, Episode 105, Reward: 9.0Worker 3, Episode 108, Reward: 10.0Worker 2, Episode 107, Reward: 9.0
#
#
# Worker 1, Episode 107, Reward: 10.0
# Worker 0, Episode 110, Reward: 8.0Worker 3, Episode 109, Reward: 10.0
#
# Worker 1, Episode 112, Reward: 9.0Worker 2, Episode 112, Reward: 10.0
#
# Worker 0, Episode 114, Reward: 8.0
# Worker 3, Episode 113, Reward: 10.0
# Worker 1, Episode 115, Reward: 9.0Worker 0, Episode 117, Reward: 9.0Worker 2, Episode 117, Reward: 11.0
# Worker 3, Episode 118, Reward: 9.0
#
#
# Worker 2, Episode 121, Reward: 9.0Worker 1, Episode 121, Reward: 10.0
#
# Worker 0, Episode 119, Reward: 10.0
# Worker 3, Episode 122, Reward: 10.0
# Worker 1, Episode 123, Reward: 9.0Worker 2, Episode 124, Reward: 9.0Worker 0, Episode 125, Reward: 9.0
#
# Worker 3, Episode 126, Reward: 10.0
# Worker 1, Episode 127, Reward: 9.0
#
# Worker 2, Episode 128, Reward: 9.0
# Worker 1, Episode 130, Reward: 9.0Worker 0, Episode 129, Reward: 10.0
# Worker 3, Episode 131, Reward: 8.0
#
# Worker 1, Episode 133, Reward: 10.0Worker 2, Episode 132, Reward: 8.0
#
# Worker 3, Episode 134, Reward: 9.0Worker 0, Episode 135, Reward: 10.0
#
# Worker 2, Episode 136, Reward: 10.0Worker 1, Episode 137, Reward: 10.0
# Worker 3, Episode 138, Reward: 9.0
#
# Worker 0, Episode 139, Reward: 10.0
# Worker 2, Episode 140, Reward: 9.0
# Worker 0, Episode 142, Reward: 9.0Worker 1, Episode 142, Reward: 10.0Worker 3, Episode 143, Reward: 9.0
#
# Worker 2, Episode 144, Reward: 9.0
#
# Worker 3, Episode 146, Reward: 9.0Worker 1, Episode 147, Reward: 10.0
# Worker 2, Episode 148, Reward: 10.0Worker 0, Episode 145, Reward: 9.0
#
#
# Worker 2, Episode 149, Reward: 9.0Worker 1, Episode 150, Reward: 10.0
#
# Worker 3, Episode 151, Reward: 9.0Worker 0, Episode 152, Reward: 9.0Worker 2, Episode 153, Reward: 9.0
#
#
# Worker 2, Episode 155, Reward: 9.0
# Worker 1, Episode 155, Reward: 10.0Worker 3, Episode 156, Reward: 10.0Worker 0, Episode 157, Reward: 9.0
#
#
# Worker 0, Episode 158, Reward: 8.0
# Worker 1, Episode 160, Reward: 9.0
# Worker 2, Episode 160, Reward: 9.0Worker 3, Episode 161, Reward: 10.0
#
# Worker 0, Episode 162, Reward: 9.0
# Worker 0, Episode 164, Reward: 9.0
# Worker 2, Episode 166, Reward: 10.0Worker 0, Episode 166, Reward: 9.0
# Worker 1, Episode 163, Reward: 10.0
#
# Worker 3, Episode 167, Reward: 10.0
# Worker 0, Episode 168, Reward: 9.0
# Worker 2, Episode 169, Reward: 10.0Worker 1, Episode 170, Reward: 9.0
#
# Worker 3, Episode 171, Reward: 9.0Worker 0, Episode 172, Reward: 8.0
#
# Worker 2, Episode 173, Reward: 8.0
# Worker 2, Episode 175, Reward: 10.0Worker 3, Episode 174, Reward: 9.0Worker 0, Episode 176, Reward: 8.0
#
#
# Worker 0, Episode 178, Reward: 10.0
# Worker 1, Episode 177, Reward: 11.0
# Worker 0, Episode 179, Reward: 10.0Worker 2, Episode 181, Reward: 10.0
#
# Worker 3, Episode 181, Reward: 10.0
# Worker 1, Episode 182, Reward: 10.0
# Worker 2, Episode 184, Reward: 10.0
# Worker 0, Episode 183, Reward: 9.0
# Worker 3, Episode 185, Reward: 9.0
# Worker 1, Episode 187, Reward: 10.0
# Worker 0, Episode 187, Reward: 9.0
# Worker 3, Episode 190, Reward: 10.0
# Worker 2, Episode 188, Reward: 10.0
# Worker 0, Episode 191, Reward: 10.0Worker 1, Episode 189, Reward: 9.0
#
# Worker 3, Episode 192, Reward: 10.0
# Worker 2, Episode 193, Reward: 10.0Worker 1, Episode 195, Reward: 10.0Worker 0, Episode 194, Reward: 10.0
#
# Worker 3, Episode 196, Reward: 10.0
# Worker 1, Episode 197, Reward: 9.0
#
# Worker 0, Episode 199, Reward: 10.0Worker 2, Episode 199, Reward: 11.0
#
# Worker 3, Episode 200, Reward: 9.0
# Worker 1, Episode 201, Reward: 11.0
# Worker 2, Episode 202, Reward: 9.0Worker 0, Episode 203, Reward: 9.0
# Worker 3, Episode 204, Reward: 9.0
#
# Worker 2, Episode 205, Reward: 10.0Worker 3, Episode 206, Reward: 9.0
#
# Worker 0, Episode 207, Reward: 10.0
# Worker 1, Episode 209, Reward: 11.0Worker 2, Episode 208, Reward: 9.0
# Worker 3, Episode 210, Reward: 9.0
# Worker 2, Episode 211, Reward: 8.0
# Worker 2, Episode 212, Reward: 10.0
#
# Worker 0, Episode 213, Reward: 9.0Worker 1, Episode 215, Reward: 10.0Worker 3, Episode 216, Reward: 9.0
#
#
# Worker 2, Episode 216, Reward: 10.0
# Worker 0, Episode 217, Reward: 10.0Worker 3, Episode 219, Reward: 9.0
# Worker 1, Episode 219, Reward: 9.0
# Worker 2, Episode 220, Reward: 9.0Worker 3, Episode 221, Reward: 11.0
#
#
# Worker 1, Episode 223, Reward: 8.0Worker 0, Episode 222, Reward: 10.0
#
# Worker 2, Episode 224, Reward: 9.0Worker 3, Episode 225, Reward: 9.0
# Worker 1, Episode 226, Reward: 10.0
#
# Worker 0, Episode 228, Reward: 9.0Worker 2, Episode 227, Reward: 10.0
# Worker 3, Episode 229, Reward: 9.0
# Worker 1, Episode 230, Reward: 10.0
#
# Worker 1, Episode 232, Reward: 8.0Worker 0, Episode 233, Reward: 9.0Worker 2, Episode 231, Reward: 10.0
#
#
# Worker 3, Episode 234, Reward: 9.0Worker 2, Episode 236, Reward: 10.0Worker 1, Episode 235, Reward: 9.0
#
#
# Worker 3, Episode 238, Reward: 10.0Worker 0, Episode 237, Reward: 9.0Worker 2, Episode 239, Reward: 9.0
#
#
# Worker 3, Episode 241, Reward: 9.0Worker 1, Episode 240, Reward: 9.0
# Worker 0, Episode 242, Reward: 8.0
# Worker 2, Episode 243, Reward: 10.0
#
# Worker 3, Episode 244, Reward: 10.0
# Worker 0, Episode 246, Reward: 8.0Worker 1, Episode 247, Reward: 10.0Worker 2, Episode 245, Reward: 10.0
#
#
# Worker 3, Episode 248, Reward: 10.0
# Worker 1, Episode 251, Reward: 9.0Worker 0, Episode 249, Reward: 10.0
# Worker 2, Episode 251, Reward: 10.0
#
# Worker 0, Episode 252, Reward: 10.0
# Worker 3, Episode 253, Reward: 9.0Worker 1, Episode 255, Reward: 9.0
# Worker 2, Episode 254, Reward: 9.0
#
# Worker 0, Episode 256, Reward: 9.0Worker 3, Episode 258, Reward: 10.0Worker 1, Episode 257, Reward: 10.0
#
#
# Worker 2, Episode 259, Reward: 10.0Worker 3, Episode 261, Reward: 9.0
# Worker 0, Episode 260, Reward: 10.0
#
# Worker 1, Episode 262, Reward: 8.0Worker 2, Episode 263, Reward: 10.0
#
# Worker 0, Episode 264, Reward: 9.0
# Worker 3, Episode 265, Reward: 9.0
# Worker 1, Episode 266, Reward: 10.0
# Worker 2, Episode 267, Reward: 10.0Worker 3, Episode 269, Reward: 9.0Worker 0, Episode 268, Reward: 10.0
#
#
# Worker 1, Episode 270, Reward: 10.0Worker 2, Episode 271, Reward: 10.0
#
# Worker 3, Episode 274, Reward: 8.0
# Worker 0, Episode 273, Reward: 9.0Worker 1, Episode 272, Reward: 9.0
#
# Worker 2, Episode 275, Reward: 8.0
# Worker 1, Episode 277, Reward: 9.0Worker 3, Episode 277, Reward: 8.0
#
# Worker 2, Episode 278, Reward: 9.0
# Worker 0, Episode 279, Reward: 9.0Worker 3, Episode 281, Reward: 9.0Worker 1, Episode 281, Reward: 9.0
#
#
# Worker 2, Episode 282, Reward: 9.0Worker 0, Episode 283, Reward: 11.0
#
# Worker 1, Episode 285, Reward: 9.0
# Worker 3, Episode 284, Reward: 9.0Worker 0, Episode 286, Reward: 8.0
#
# Worker 2, Episode 287, Reward: 9.0Worker 1, Episode 288, Reward: 10.0
#
# Worker 0, Episode 289, Reward: 10.0
# Worker 1, Episode 292, Reward: 8.0Worker 2, Episode 292, Reward: 10.0Worker 3, Episode 290, Reward: 9.0Worker 0, Episode 293, Reward: 10.0
#
#
#
# Worker 3, Episode 294, Reward: 9.0Worker 0, Episode 296, Reward: 9.0Worker 2, Episode 295, Reward: 9.0
#
#
# Worker 1, Episode 297, Reward: 8.0
# Worker 0, Episode 299, Reward: 9.0Worker 3, Episode 298, Reward: 9.0
#
# Worker 2, Episode 300, Reward: 9.0
# Worker 1, Episode 301, Reward: 8.0
# Worker 0, Episode 302, Reward: 9.0Worker 3, Episode 303, Reward: 9.0
#
# Worker 1, Episode 305, Reward: 9.0
# Worker 2, Episode 304, Reward: 10.0
# Worker 1, Episode 306, Reward: 10.0Worker 2, Episode 308, Reward: 8.0Worker 0, Episode 307, Reward: 10.0
#
#
# Worker 3, Episode 309, Reward: 10.0Worker 1, Episode 311, Reward: 9.0Worker 2, Episode 311, Reward: 9.0
#
#
# Worker 0, Episode 312, Reward: 10.0
# Worker 3, Episode 315, Reward: 10.0Worker 1, Episode 313, Reward: 9.0Worker 2, Episode 314, Reward: 10.0
#
#
# Worker 0, Episode 316, Reward: 8.0
# Worker 1, Episode 317, Reward: 10.0Worker 3, Episode 318, Reward: 9.0
#
# Worker 0, Episode 319, Reward: 9.0Worker 1, Episode 320, Reward: 11.0
# Worker 2, Episode 321, Reward: 11.0
# Worker 3, Episode 322, Reward: 8.0
#
# Worker 1, Episode 323, Reward: 10.0Worker 0, Episode 324, Reward: 9.0
# Worker 2, Episode 325, Reward: 10.0
# Worker 3, Episode 326, Reward: 10.0Worker 1, Episode 327, Reward: 8.0
#
# Worker 1, Episode 328, Reward: 10.0
#
# Worker 0, Episode 329, Reward: 9.0
# Worker 3, Episode 330, Reward: 10.0Worker 1, Episode 331, Reward: 10.0Worker 0, Episode 332, Reward: 10.0
#
#
# Worker 2, Episode 333, Reward: 10.0
# Worker 0, Episode 334, Reward: 8.0
# Worker 1, Episode 336, Reward: 10.0Worker 2, Episode 337, Reward: 9.0Worker 3, Episode 335, Reward: 10.0
# Worker 0, Episode 338, Reward: 9.0
#
#
# Worker 0, Episode 340, Reward: 10.0Worker 1, Episode 339, Reward: 10.0
#
# Worker 3, Episode 342, Reward: 9.0Worker 2, Episode 341, Reward: 9.0
#
# Worker 1, Episode 343, Reward: 10.0Worker 0, Episode 344, Reward: 10.0
#
# Worker 2, Episode 345, Reward: 10.0
# Worker 3, Episode 346, Reward: 10.0
# Worker 1, Episode 347, Reward: 9.0Worker 2, Episode 349, Reward: 10.0
#
# Worker 0, Episode 348, Reward: 10.0
# Worker 2, Episode 352, Reward: 10.0Worker 3, Episode 351, Reward: 8.0Worker 1, Episode 352, Reward: 10.0
#
#
# Worker 0, Episode 353, Reward: 10.0Worker 2, Episode 354, Reward: 8.0
#
# Worker 0, Episode 355, Reward: 8.0Worker 1, Episode 357, Reward: 10.0Worker 3, Episode 357, Reward: 10.0
# Worker 2, Episode 358, Reward: 8.0
#
#
# Worker 1, Episode 361, Reward: 9.0Worker 3, Episode 359, Reward: 10.0Worker 0, Episode 360, Reward: 10.0
#
#
# Worker 2, Episode 362, Reward: 9.0
# Worker 1, Episode 363, Reward: 10.0Worker 3, Episode 365, Reward: 10.0
# Worker 0, Episode 364, Reward: 8.0Worker 2, Episode 366, Reward: 8.0
#
#
# Worker 3, Episode 368, Reward: 10.0Worker 1, Episode 369, Reward: 9.0
#
# Worker 0, Episode 368, Reward: 10.0
# Worker 1, Episode 370, Reward: 9.0
# Worker 2, Episode 371, Reward: 10.0Worker 3, Episode 372, Reward: 10.0
# Worker 1, Episode 373, Reward: 9.0
# Worker 0, Episode 374, Reward: 9.0
# Worker 1, Episode 375, Reward: 10.0Worker 2, Episode 376, Reward: 10.0
#
# Worker 3, Episode 377, Reward: 10.0
#
# Worker 1, Episode 379, Reward: 9.0Worker 2, Episode 379, Reward: 9.0
# Worker 0, Episode 380, Reward: 11.0
#
# Worker 3, Episode 381, Reward: 9.0
# Worker 2, Episode 382, Reward: 9.0Worker 0, Episode 383, Reward: 9.0
#
# Worker 1, Episode 384, Reward: 9.0
# Worker 3, Episode 385, Reward: 9.0
# Worker 1, Episode 386, Reward: 9.0
# Worker 2, Episode 387, Reward: 9.0Worker 0, Episode 388, Reward: 9.0
#
# Worker 1, Episode 389, Reward: 9.0Worker 3, Episode 390, Reward: 10.0
#
# Worker 0, Episode 392, Reward: 10.0Worker 2, Episode 391, Reward: 10.0
# Worker 3, Episode 394, Reward: 9.0Worker 1, Episode 393, Reward: 9.0
#
#
# Worker 0, Episode 396, Reward: 9.0Worker 2, Episode 395, Reward: 8.0
#
# Worker 3, Episode 397, Reward: 9.0Worker 1, Episode 398, Reward: 10.0
#
# Worker 2, Episode 399, Reward: 10.0Worker 3, Episode 400, Reward: 9.0
# Worker 0, Episode 401, Reward: 9.0
# Worker 3, Episode 402, Reward: 9.0
#
# Worker 2, Episode 404, Reward: 8.0Worker 1, Episode 403, Reward: 8.0
#
# Worker 3, Episode 405, Reward: 8.0Worker 1, Episode 406, Reward: 8.0
#
# Worker 0, Episode 407, Reward: 8.0
# Worker 2, Episode 408, Reward: 9.0Worker 0, Episode 409, Reward: 9.0
# Worker 1, Episode 410, Reward: 10.0
# Worker 3, Episode 411, Reward: 10.0Worker 0, Episode 412, Reward: 10.0
#
# Worker 2, Episode 413, Reward: 10.0
#
# Worker 1, Episode 414, Reward: 9.0Worker 2, Episode 415, Reward: 9.0
#
# Worker 0, Episode 416, Reward: 8.0
# Worker 2, Episode 418, Reward: 9.0Worker 3, Episode 417, Reward: 10.0
#
# Worker 1, Episode 419, Reward: 9.0
# Worker 0, Episode 421, Reward: 9.0Worker 2, Episode 420, Reward: 9.0
# Worker 3, Episode 422, Reward: 10.0
#
# Worker 1, Episode 423, Reward: 8.0Worker 0, Episode 424, Reward: 8.0
# Worker 2, Episode 425, Reward: 10.0
#
# Worker 3, Episode 426, Reward: 9.0Worker 0, Episode 427, Reward: 9.0Worker 2, Episode 428, Reward: 9.0
#
# Worker 1, Episode 429, Reward: 8.0
#
# Worker 3, Episode 430, Reward: 9.0Worker 0, Episode 432, Reward: 9.0
# Worker 2, Episode 432, Reward: 9.0
# Worker 1, Episode 433, Reward: 8.0
#
# Worker 0, Episode 434, Reward: 10.0Worker 3, Episode 435, Reward: 8.0
# Worker 2, Episode 436, Reward: 8.0Worker 1, Episode 437, Reward: 9.0
#
#
# Worker 3, Episode 438, Reward: 11.0
# Worker 1, Episode 439, Reward: 9.0
# Worker 0, Episode 440, Reward: 10.0
# Worker 2, Episode 441, Reward: 9.0Worker 3, Episode 442, Reward: 10.0
#
# Worker 1, Episode 444, Reward: 10.0Worker 0, Episode 443, Reward: 8.0
#
# Worker 1, Episode 446, Reward: 10.0
# Worker 3, Episode 447, Reward: 9.0Worker 2, Episode 445, Reward: 10.0
# Worker 1, Episode 449, Reward: 9.0Worker 0, Episode 449, Reward: 9.0
#
#
# Worker 3, Episode 450, Reward: 9.0Worker 0, Episode 451, Reward: 10.0Worker 1, Episode 453, Reward: 8.0
# Worker 2, Episode 453, Reward: 9.0
#
#
# Worker 3, Episode 454, Reward: 8.0Worker 0, Episode 455, Reward: 10.0
#
# Worker 1, Episode 456, Reward: 9.0Worker 2, Episode 457, Reward: 10.0Worker 0, Episode 458, Reward: 10.0
#
#
# Worker 3, Episode 459, Reward: 10.0Worker 1, Episode 460, Reward: 10.0
#
# Worker 0, Episode 461, Reward: 9.0Worker 3, Episode 463, Reward: 8.0Worker 2, Episode 462, Reward: 9.0
#
#
# Worker 1, Episode 465, Reward: 10.0Worker 0, Episode 464, Reward: 9.0
# Worker 3, Episode 466, Reward: 10.0
#
# Worker 2, Episode 467, Reward: 9.0
# Worker 1, Episode 468, Reward: 8.0
# Worker 3, Episode 469, Reward: 8.0
# Worker 2, Episode 470, Reward: 10.0Worker 0, Episode 471, Reward: 11.0Worker 1, Episode 472, Reward: 8.0
#
#
# Worker 2, Episode 474, Reward: 10.0Worker 3, Episode 474, Reward: 9.0
# Worker 1, Episode 476, Reward: 9.0
#
# Worker 0, Episode 475, Reward: 10.0
# Worker 1, Episode 477, Reward: 8.0
# Worker 3, Episode 478, Reward: 9.0
# Worker 0, Episode 480, Reward: 10.0Worker 2, Episode 479, Reward: 8.0
#
# Worker 1, Episode 481, Reward: 9.0Worker 3, Episode 482, Reward: 10.0
#
# Worker 2, Episode 484, Reward: 8.0
# Worker 0, Episode 483, Reward: 9.0Worker 2, Episode 485, Reward: 9.0
# Worker 1, Episode 487, Reward: 10.0
#
# Worker 3, Episode 486, Reward: 10.0
# Worker 0, Episode 488, Reward: 10.0Worker 2, Episode 489, Reward: 10.0
# Worker 1, Episode 490, Reward: 9.0
#
# Worker 2, Episode 491, Reward: 10.0
# Worker 0, Episode 493, Reward: 9.0Worker 3, Episode 492, Reward: 10.0Worker 1, Episode 494, Reward: 9.0
#
#
# Worker 3, Episode 497, Reward: 10.0
# Worker 2, Episode 496, Reward: 9.0Worker 0, Episode 495, Reward: 10.0
#
# Worker 0, Episode 499, Reward: 10.0
# Worker 1, Episode 498, Reward: 10.0
# Worker 3, Episode 501, Reward: 9.0Worker 2, Episode 501, Reward: 9.0
# Worker 0, Episode 502, Reward: 10.0
#
# Worker 1, Episode 503, Reward: 9.0
# Worker 3, Episode 504, Reward: 10.0Worker 2, Episode 506, Reward: 9.0Worker 0, Episode 505, Reward: 8.0
#
#
# Worker 1, Episode 507, Reward: 9.0Worker 0, Episode 508, Reward: 10.0
#
# Worker 3, Episode 509, Reward: 10.0
# Worker 2, Episode 510, Reward: 9.0
# Worker 1, Episode 511, Reward: 8.0
# Worker 2, Episode 512, Reward: 8.0Worker 0, Episode 513, Reward: 10.0Worker 3, Episode 514, Reward: 10.0
#
#
# Worker 1, Episode 515, Reward: 10.0Worker 2, Episode 516, Reward: 9.0Worker 3, Episode 517, Reward: 10.0
# Worker 0, Episode 518, Reward: 10.0
#
#
# Worker 2, Episode 521, Reward: 10.0Worker 1, Episode 521, Reward: 9.0
# Worker 0, Episode 519, Reward: 9.0
#
# Worker 1, Episode 522, Reward: 8.0Worker 0, Episode 524, Reward: 10.0
# Worker 3, Episode 523, Reward: 10.0Worker 2, Episode 525, Reward: 10.0
#
#
# Worker 2, Episode 526, Reward: 10.0
# Worker 1, Episode 528, Reward: 10.0Worker 0, Episode 527, Reward: 9.0
#
# Worker 2, Episode 529, Reward: 8.0
# Worker 3, Episode 530, Reward: 10.0
# Worker 1, Episode 531, Reward: 9.0Worker 2, Episode 532, Reward: 8.0
#
# Worker 0, Episode 533, Reward: 10.0
# Worker 1, Episode 534, Reward: 10.0
# Worker 3, Episode 536, Reward: 8.0Worker 2, Episode 535, Reward: 8.0
# Worker 1, Episode 537, Reward: 9.0
#
# Worker 0, Episode 538, Reward: 9.0
# Worker 1, Episode 540, Reward: 10.0Worker 2, Episode 541, Reward: 9.0Worker 3, Episode 541, Reward: 10.0
#
#
# Worker 0, Episode 542, Reward: 10.0
# Worker 2, Episode 543, Reward: 9.0Worker 3, Episode 545, Reward: 10.0Worker 1, Episode 544, Reward: 10.0
#
#
# Worker 0, Episode 546, Reward: 10.0
# Worker 1, Episode 547, Reward: 10.0
# Worker 3, Episode 548, Reward: 9.0
# Worker 1, Episode 550, Reward: 9.0Worker 0, Episode 549, Reward: 10.0
#
# Worker 3, Episode 551, Reward: 10.0
# Worker 2, Episode 552, Reward: 10.0Worker 1, Episode 553, Reward: 10.0
#
# Worker 3, Episode 554, Reward: 10.0
# Worker 1, Episode 557, Reward: 8.0Worker 0, Episode 555, Reward: 9.0Worker 2, Episode 556, Reward: 9.0
#
#
# Worker 2, Episode 558, Reward: 8.0
# Worker 2, Episode 559, Reward: 10.0Worker 3, Episode 561, Reward: 10.0
#
# Worker 0, Episode 561, Reward: 10.0Worker 1, Episode 562, Reward: 10.0
#
# Worker 3, Episode 563, Reward: 9.0
# Worker 1, Episode 564, Reward: 9.0
# Worker 2, Episode 565, Reward: 10.0
# Worker 0, Episode 567, Reward: 9.0Worker 3, Episode 566, Reward: 9.0
#
# Worker 1, Episode 568, Reward: 10.0
# Worker 2, Episode 569, Reward: 10.0Worker 3, Episode 570, Reward: 9.0
#
# Worker 1, Episode 572, Reward: 9.0
# Worker 3, Episode 573, Reward: 8.0Worker 0, Episode 571, Reward: 9.0
#
# Worker 1, Episode 575, Reward: 10.0Worker 3, Episode 576, Reward: 10.0Worker 2, Episode 575, Reward: 10.0
#
#
# Worker 0, Episode 577, Reward: 10.0
# Worker 2, Episode 578, Reward: 9.0Worker 3, Episode 580, Reward: 9.0Worker 1, Episode 580, Reward: 9.0
#
# Worker 0, Episode 581, Reward: 8.0
#
# Worker 3, Episode 582, Reward: 8.0Worker 2, Episode 583, Reward: 9.0
#
# Worker 0, Episode 584, Reward: 10.0
# Worker 1, Episode 586, Reward: 9.0Worker 2, Episode 586, Reward: 9.0Worker 0, Episode 587, Reward: 10.0Worker 3, Episode 588, Reward: 10.0
#
#
#
# Worker 1, Episode 591, Reward: 8.0Worker 2, Episode 589, Reward: 8.0Worker 0, Episode 591, Reward: 10.0
# Worker 3, Episode 592, Reward: 10.0
#
#
# Worker 0, Episode 593, Reward: 9.0
# Worker 3, Episode 596, Reward: 9.0Worker 1, Episode 595, Reward: 9.0Worker 2, Episode 595, Reward: 10.0
#
#
# Worker 3, Episode 597, Reward: 9.0Worker 0, Episode 598, Reward: 9.0
#
# Worker 1, Episode 599, Reward: 9.0Worker 2, Episode 600, Reward: 10.0
# Worker 0, Episode 601, Reward: 8.0
#
# Worker 3, Episode 602, Reward: 9.0Worker 0, Episode 603, Reward: 10.0
#
# Worker 3, Episode 606, Reward: 10.0Worker 1, Episode 604, Reward: 10.0
# Worker 2, Episode 605, Reward: 10.0
# Worker 0, Episode 607, Reward: 10.0
#
# Worker 1, Episode 608, Reward: 10.0
# Worker 3, Episode 609, Reward: 10.0
# Worker 2, Episode 610, Reward: 10.0Worker 0, Episode 611, Reward: 11.0
#
# Worker 3, Episode 613, Reward: 9.0
# Worker 1, Episode 612, Reward: 10.0
# Worker 2, Episode 614, Reward: 9.0
# Worker 3, Episode 615, Reward: 9.0Worker 0, Episode 616, Reward: 9.0
#
# Worker 2, Episode 618, Reward: 10.0Worker 1, Episode 617, Reward: 8.0
# Worker 3, Episode 619, Reward: 10.0
#
# Worker 0, Episode 620, Reward: 9.0
# Worker 1, Episode 621, Reward: 10.0Worker 2, Episode 622, Reward: 10.0
# Worker 3, Episode 623, Reward: 10.0Worker 0, Episode 624, Reward: 10.0
#
#
# Worker 3, Episode 626, Reward: 10.0Worker 1, Episode 625, Reward: 8.0
#
# Worker 3, Episode 629, Reward: 9.0Worker 2, Episode 628, Reward: 10.0
#
# Worker 0, Episode 628, Reward: 9.0
# Worker 3, Episode 631, Reward: 10.0Worker 1, Episode 630, Reward: 9.0
# Worker 2, Episode 632, Reward: 8.0
#
# Worker 0, Episode 633, Reward: 10.0Worker 3, Episode 635, Reward: 10.0
# Worker 2, Episode 634, Reward: 9.0
#
# Worker 1, Episode 636, Reward: 10.0
# Worker 3, Episode 637, Reward: 10.0
# Worker 0, Episode 639, Reward: 9.0Worker 2, Episode 638, Reward: 9.0
#
# Worker 0, Episode 642, Reward: 11.0Worker 3, Episode 640, Reward: 9.0Worker 1, Episode 641, Reward: 11.0
#
#
# Worker 0, Episode 644, Reward: 10.0Worker 3, Episode 645, Reward: 10.0
# Worker 2, Episode 644, Reward: 11.0Worker 1, Episode 646, Reward: 10.0
#
#
# Worker 0, Episode 647, Reward: 10.0
# Worker 1, Episode 649, Reward: 10.0Worker 2, Episode 649, Reward: 10.0Worker 3, Episode 650, Reward: 9.0
#
#
# Worker 0, Episode 651, Reward: 9.0
# Worker 3, Episode 652, Reward: 10.0
# Worker 1, Episode 655, Reward: 10.0Worker 0, Episode 653, Reward: 9.0
#
# Worker 2, Episode 654, Reward: 9.0Worker 3, Episode 656, Reward: 9.0
#
# Worker 0, Episode 657, Reward: 9.0Worker 2, Episode 658, Reward: 10.0
# Worker 1, Episode 659, Reward: 10.0
#
# Worker 3, Episode 660, Reward: 10.0
# Worker 2, Episode 661, Reward: 9.0
# Worker 0, Episode 663, Reward: 10.0Worker 1, Episode 664, Reward: 8.0Worker 3, Episode 663, Reward: 9.0
#
#
# Worker 1, Episode 667, Reward: 10.0Worker 3, Episode 666, Reward: 9.0Worker 2, Episode 665, Reward: 10.0
#
#
# Worker 0, Episode 668, Reward: 10.0
# Worker 3, Episode 669, Reward: 10.0
# Worker 2, Episode 670, Reward: 10.0Worker 1, Episode 671, Reward: 10.0Worker 0, Episode 672, Reward: 9.0
#
#
# Worker 3, Episode 673, Reward: 10.0
# Worker 1, Episode 675, Reward: 9.0Worker 2, Episode 675, Reward: 8.0
#
# Worker 0, Episode 676, Reward: 9.0
# Worker 3, Episode 677, Reward: 10.0Worker 1, Episode 678, Reward: 9.0
# Worker 2, Episode 679, Reward: 9.0
#
# Worker 0, Episode 680, Reward: 9.0
# Worker 2, Episode 681, Reward: 10.0Worker 3, Episode 682, Reward: 10.0
#
# Worker 0, Episode 684, Reward: 9.0
# Worker 1, Episode 683, Reward: 8.0
# Worker 1, Episode 685, Reward: 9.0Worker 3, Episode 687, Reward: 8.0
#
# Worker 0, Episode 686, Reward: 9.0Worker 2, Episode 688, Reward: 10.0
#
# Worker 1, Episode 689, Reward: 9.0Worker 3, Episode 690, Reward: 10.0
# Worker 2, Episode 692, Reward: 9.0
# Worker 0, Episode 692, Reward: 9.0
# Worker 1, Episode 693, Reward: 10.0
#
# Worker 2, Episode 695, Reward: 8.0
# Worker 3, Episode 694, Reward: 8.0
# Worker 2, Episode 696, Reward: 8.0
# Worker 1, Episode 697, Reward: 10.0Worker 3, Episode 699, Reward: 10.0
# Worker 0, Episode 698, Reward: 9.0
#
# Worker 2, Episode 700, Reward: 10.0Worker 3, Episode 701, Reward: 10.0
#
# Worker 0, Episode 702, Reward: 8.0Worker 1, Episode 703, Reward: 9.0
#
# Worker 3, Episode 705, Reward: 10.0Worker 2, Episode 704, Reward: 9.0Worker 1, Episode 706, Reward: 8.0
# Worker 0, Episode 707, Reward: 10.0
#
#
# Worker 3, Episode 710, Reward: 9.0Worker 1, Episode 709, Reward: 10.0Worker 2, Episode 710, Reward: 8.0
#
# Worker 0, Episode 711, Reward: 9.0
#
# Worker 1, Episode 712, Reward: 9.0Worker 2, Episode 713, Reward: 9.0
# Worker 0, Episode 714, Reward: 10.0
# Worker 3, Episode 715, Reward: 11.0
#
# Worker 1, Episode 716, Reward: 10.0Worker 0, Episode 717, Reward: 9.0
#
# Worker 2, Episode 718, Reward: 11.0Worker 3, Episode 719, Reward: 10.0
#
# Worker 0, Episode 720, Reward: 9.0
# Worker 1, Episode 721, Reward: 10.0
# Worker 2, Episode 722, Reward: 8.0
# Worker 1, Episode 723, Reward: 8.0Worker 0, Episode 725, Reward: 9.0Worker 3, Episode 725, Reward: 10.0
#
#
# Worker 2, Episode 726, Reward: 10.0
# Worker 0, Episode 727, Reward: 9.0
# Worker 1, Episode 730, Reward: 10.0Worker 3, Episode 728, Reward: 11.0Worker 2, Episode 729, Reward: 10.0
#
#
# Worker 0, Episode 731, Reward: 10.0
# Worker 2, Episode 733, Reward: 9.0Worker 3, Episode 733, Reward: 10.0
# Worker 1, Episode 734, Reward: 9.0Worker 0, Episode 735, Reward: 10.0
#
#
# Worker 0, Episode 737, Reward: 9.0Worker 2, Episode 736, Reward: 10.0Worker 3, Episode 739, Reward: 10.0
# Worker 1, Episode 739, Reward: 10.0
#
#
# Worker 3, Episode 740, Reward: 9.0Worker 0, Episode 741, Reward: 9.0
#
# Worker 1, Episode 742, Reward: 9.0
# Worker 2, Episode 744, Reward: 11.0
# Worker 1, Episode 744, Reward: 9.0Worker 0, Episode 745, Reward: 11.0
# Worker 3, Episode 746, Reward: 10.0
#
# Worker 1, Episode 749, Reward: 9.0Worker 0, Episode 749, Reward: 8.0Worker 3, Episode 750, Reward: 9.0Worker 2, Episode 749, Reward: 10.0
#
#
#
# Worker 2, Episode 751, Reward: 9.0
# Worker 0, Episode 752, Reward: 10.0Worker 1, Episode 753, Reward: 10.0
#
# Worker 2, Episode 755, Reward: 8.0Worker 3, Episode 754, Reward: 9.0
#
# Worker 0, Episode 756, Reward: 8.0Worker 2, Episode 758, Reward: 9.0
#
# Worker 1, Episode 757, Reward: 10.0
# Worker 3, Episode 759, Reward: 9.0
# Worker 0, Episode 761, Reward: 10.0Worker 2, Episode 760, Reward: 10.0
# Worker 1, Episode 762, Reward: 11.0
#
# Worker 3, Episode 763, Reward: 10.0
# Worker 0, Episode 764, Reward: 8.0
# Worker 2, Episode 765, Reward: 9.0Worker 1, Episode 766, Reward: 8.0Worker 3, Episode 767, Reward: 9.0
#
#
# Worker 0, Episode 768, Reward: 9.0
# Worker 3, Episode 769, Reward: 9.0Worker 1, Episode 771, Reward: 9.0
#
# Worker 1, Episode 772, Reward: 9.0Worker 2, Episode 770, Reward: 10.0
#
# Worker 3, Episode 774, Reward: 9.0Worker 1, Episode 775, Reward: 9.0Worker 0, Episode 773, Reward: 9.0
#
#
# Worker 0, Episode 776, Reward: 9.0
# Worker 2, Episode 777, Reward: 9.0
# Worker 1, Episode 779, Reward: 9.0Worker 3, Episode 779, Reward: 10.0
#
# Worker 0, Episode 780, Reward: 10.0
# Worker 2, Episode 782, Reward: 11.0Worker 1, Episode 783, Reward: 10.0Worker 3, Episode 781, Reward: 9.0
#
#
# Worker 0, Episode 784, Reward: 10.0
# Worker 1, Episode 785, Reward: 9.0
# Worker 3, Episode 787, Reward: 10.0Worker 2, Episode 786, Reward: 9.0
#
# Worker 0, Episode 788, Reward: 10.0Worker 3, Episode 789, Reward: 9.0
# Worker 1, Episode 790, Reward: 9.0
#
# Worker 0, Episode 792, Reward: 9.0
# Worker 2, Episode 791, Reward: 10.0
# Worker 3, Episode 793, Reward: 8.0
# Worker 1, Episode 794, Reward: 10.0Worker 0, Episode 795, Reward: 10.0Worker 2, Episode 796, Reward: 9.0
#
#
# Worker 0, Episode 797, Reward: 9.0
# Worker 3, Episode 798, Reward: 9.0Worker 1, Episode 799, Reward: 9.0
# Worker 2, Episode 800, Reward: 10.0
# Worker 0, Episode 801, Reward: 11.0
# Worker 3, Episode 802, Reward: 8.0
#
# Worker 1, Episode 803, Reward: 9.0Worker 2, Episode 805, Reward: 9.0
# Worker 0, Episode 804, Reward: 8.0
#
# Worker 0, Episode 806, Reward: 10.0Worker 2, Episode 808, Reward: 8.0
#
# Worker 3, Episode 809, Reward: 11.0
# Worker 1, Episode 807, Reward: 10.0
# Worker 2, Episode 811, Reward: 9.0
# Worker 3, Episode 812, Reward: 9.0
# Worker 0, Episode 811, Reward: 9.0Worker 2, Episode 813, Reward: 9.0
#
# Worker 3, Episode 814, Reward: 10.0Worker 1, Episode 815, Reward: 9.0
#
# Worker 2, Episode 816, Reward: 10.0Worker 0, Episode 817, Reward: 10.0Worker 1, Episode 819, Reward: 8.0Worker 3, Episode 818, Reward: 9.0
#
#
#
# Worker 0, Episode 821, Reward: 9.0Worker 2, Episode 821, Reward: 9.0Worker 3, Episode 822, Reward: 8.0
# Worker 1, Episode 823, Reward: 9.0
#
#
# Worker 3, Episode 824, Reward: 10.0Worker 1, Episode 826, Reward: 9.0
# Worker 0, Episode 827, Reward: 9.0
# Worker 2, Episode 826, Reward: 8.0
#
# Worker 0, Episode 828, Reward: 9.0
# Worker 1, Episode 830, Reward: 11.0Worker 2, Episode 829, Reward: 8.0Worker 3, Episode 831, Reward: 10.0
#
#
# Worker 0, Episode 832, Reward: 10.0Worker 3, Episode 833, Reward: 9.0Worker 2, Episode 834, Reward: 9.0
#
#
# Worker 1, Episode 835, Reward: 8.0
# Worker 0, Episode 836, Reward: 9.0Worker 2, Episode 838, Reward: 10.0Worker 3, Episode 838, Reward: 10.0
#
# Worker 1, Episode 839, Reward: 9.0
# Worker 3, Episode 840, Reward: 9.0
#
# Worker 0, Episode 842, Reward: 9.0Worker 2, Episode 841, Reward: 9.0
#
# Worker 3, Episode 843, Reward: 9.0
# Worker 1, Episode 844, Reward: 9.0Worker 3, Episode 845, Reward: 10.0
#
# Worker 2, Episode 846, Reward: 9.0
# Worker 0, Episode 847, Reward: 8.0
# Worker 2, Episode 848, Reward: 10.0
# Worker 3, Episode 850, Reward: 8.0Worker 1, Episode 850, Reward: 10.0
#
# Worker 0, Episode 851, Reward: 10.0
# Worker 1, Episode 852, Reward: 9.0Worker 3, Episode 854, Reward: 8.0Worker 2, Episode 854, Reward: 9.0
#
#
# Worker 1, Episode 856, Reward: 10.0Worker 0, Episode 855, Reward: 10.0
#
# Worker 0, Episode 857, Reward: 9.0
# Worker 2, Episode 859, Reward: 8.0
# Worker 3, Episode 859, Reward: 9.0
# Worker 1, Episode 860, Reward: 9.0Worker 0, Episode 861, Reward: 9.0
#
# Worker 2, Episode 862, Reward: 9.0
# Worker 3, Episode 864, Reward: 9.0
# Worker 1, Episode 864, Reward: 10.0
# Worker 3, Episode 866, Reward: 8.0Worker 0, Episode 866, Reward: 10.0
#
# Worker 2, Episode 868, Reward: 10.0Worker 1, Episode 867, Reward: 10.0
# Worker 0, Episode 869, Reward: 10.0
#
# Worker 0, Episode 870, Reward: 8.0Worker 2, Episode 871, Reward: 10.0
#
# Worker 1, Episode 872, Reward: 8.0Worker 3, Episode 873, Reward: 10.0Worker 2, Episode 874, Reward: 10.0
#
#
# Worker 2, Episode 876, Reward: 8.0
# Worker 0, Episode 875, Reward: 10.0
# Worker 1, Episode 877, Reward: 10.0
# Worker 3, Episode 878, Reward: 10.0Worker 0, Episode 880, Reward: 10.0Worker 2, Episode 880, Reward: 9.0
#
#
# Worker 3, Episode 881, Reward: 9.0
# Worker 0, Episode 882, Reward: 10.0Worker 1, Episode 883, Reward: 10.0
# Worker 2, Episode 884, Reward: 8.0
#
# Worker 3, Episode 885, Reward: 10.0Worker 0, Episode 886, Reward: 9.0Worker 1, Episode 887, Reward: 9.0
# Worker 2, Episode 888, Reward: 9.0
#
#
# Worker 0, Episode 889, Reward: 9.0Worker 1, Episode 890, Reward: 10.0
#
# Worker 2, Episode 892, Reward: 9.0Worker 3, Episode 892, Reward: 9.0
#
# Worker 0, Episode 893, Reward: 8.0
# Worker 1, Episode 894, Reward: 11.0
# Worker 2, Episode 896, Reward: 9.0Worker 3, Episode 895, Reward: 10.0
#
# Worker 0, Episode 897, Reward: 9.0Worker 1, Episode 898, Reward: 10.0
#
# Worker 3, Episode 899, Reward: 10.0Worker 1, Episode 900, Reward: 10.0
#
# Worker 0, Episode 902, Reward: 10.0Worker 2, Episode 901, Reward: 10.0
#
# Worker 0, Episode 903, Reward: 10.0
# Worker 3, Episode 904, Reward: 9.0Worker 1, Episode 905, Reward: 9.0
#
# Worker 2, Episode 906, Reward: 9.0
# Worker 1, Episode 908, Reward: 10.0
# Worker 0, Episode 907, Reward: 10.0Worker 3, Episode 909, Reward: 10.0
#
# Worker 2, Episode 911, Reward: 9.0
# Worker 3, Episode 912, Reward: 9.0Worker 1, Episode 910, Reward: 10.0
#
# Worker 0, Episode 913, Reward: 9.0
# Worker 2, Episode 915, Reward: 10.0Worker 3, Episode 916, Reward: 10.0Worker 1, Episode 916, Reward: 9.0
# Worker 0, Episode 917, Reward: 11.0
#
#
# Worker 2, Episode 918, Reward: 10.0
# Worker 1, Episode 920, Reward: 9.0Worker 3, Episode 920, Reward: 9.0
# Worker 0, Episode 921, Reward: 10.0
#
# Worker 2, Episode 922, Reward: 10.0
# Worker 0, Episode 924, Reward: 10.0Worker 1, Episode 925, Reward: 9.0Worker 3, Episode 923, Reward: 8.0
#
#
# Worker 1, Episode 926, Reward: 9.0
# Worker 2, Episode 927, Reward: 9.0
# Worker 0, Episode 929, Reward: 10.0
# Worker 3, Episode 928, Reward: 10.0Worker 1, Episode 930, Reward: 9.0
#
# Worker 0, Episode 931, Reward: 9.0Worker 2, Episode 932, Reward: 9.0
#
# Worker 1, Episode 934, Reward: 9.0Worker 0, Episode 935, Reward: 8.0Worker 3, Episode 933, Reward: 9.0
#
#
# Worker 2, Episode 936, Reward: 11.0
# Worker 0, Episode 938, Reward: 10.0Worker 1, Episode 938, Reward: 10.0Worker 3, Episode 939, Reward: 9.0
#
#
# Worker 2, Episode 940, Reward: 8.0
# Worker 3, Episode 942, Reward: 8.0Worker 1, Episode 941, Reward: 10.0
# Worker 0, Episode 943, Reward: 10.0
#
# Worker 3, Episode 945, Reward: 9.0
# Worker 2, Episode 945, Reward: 9.0
# Worker 0, Episode 946, Reward: 10.0Worker 1, Episode 947, Reward: 10.0
#
# Worker 3, Episode 948, Reward: 10.0Worker 0, Episode 949, Reward: 9.0
#
# Worker 2, Episode 950, Reward: 8.0
# Worker 1, Episode 951, Reward: 10.0Worker 3, Episode 952, Reward: 9.0Worker 0, Episode 953, Reward: 9.0
#
#
# Worker 3, Episode 954, Reward: 10.0Worker 0, Episode 955, Reward: 8.0
#
# Worker 2, Episode 956, Reward: 9.0Worker 1, Episode 957, Reward: 9.0
# Worker 0, Episode 958, Reward: 9.0
#
# Worker 3, Episode 959, Reward: 11.0Worker 1, Episode 960, Reward: 8.0
# Worker 2, Episode 961, Reward: 10.0Worker 0, Episode 962, Reward: 10.0
#
#
# Worker 2, Episode 965, Reward: 9.0Worker 3, Episode 966, Reward: 9.0Worker 0, Episode 963, Reward: 10.0Worker 1, Episode 964, Reward: 10.0
#
#
#
# Worker 3, Episode 968, Reward: 9.0
# Worker 1, Episode 968, Reward: 9.0Worker 0, Episode 969, Reward: 10.0Worker 2, Episode 970, Reward: 9.0
#
#
# Worker 1, Episode 972, Reward: 9.0Worker 3, Episode 972, Reward: 10.0
#
# Worker 2, Episode 973, Reward: 8.0
# Worker 0, Episode 974, Reward: 9.0
# Worker 3, Episode 975, Reward: 9.0
# Worker 1, Episode 976, Reward: 9.0
# Worker 2, Episode 977, Reward: 11.0
# Worker 0, Episode 980, Reward: 10.0Worker 1, Episode 980, Reward: 10.0Worker 3, Episode 980, Reward: 9.0
#
#
# Worker 2, Episode 981, Reward: 8.0Worker 3, Episode 982, Reward: 8.0
# Worker 1, Episode 984, Reward: 9.0Worker 0, Episode 983, Reward: 8.0
#
#
# Worker 2, Episode 985, Reward: 9.0Worker 0, Episode 986, Reward: 9.0
# Worker 1, Episode 987, Reward: 8.0
# Worker 3, Episode 988, Reward: 10.0
# Worker 2, Episode 989, Reward: 10.0
#
# Worker 0, Episode 990, Reward: 8.0
# Worker 3, Episode 991, Reward: 9.0Worker 2, Episode 992, Reward: 10.0
#
# Worker 1, Episode 993, Reward: 8.0
# Worker 3, Episode 994, Reward: 8.0
# Worker 0, Episode 995, Reward: 9.0
# Worker 2, Episode 997, Reward: 8.0Worker 1, Episode 996, Reward: 10.0
#
# Worker 2, Episode 998, Reward: 9.0Worker 0, Episode 999, Reward: 9.0
# Worker 3, Episode 1000, Reward: 9.0
#
# Worker 1, Episode 1001, Reward: 10.0
# Treinamento concluído!
# Média de recompensa por episódio: 9.52

# %% [markdown]
# ---
#
# ### **Explicação do Código**
# 1. **Rede Actor-Critic Compartilhada**:
#    - A classe `ActorCritic` é usada como a arquitetura para todos os trabalhadores. O modelo global é compartilhado entre os processos.
#
# 2. **Trabalhadores (`worker`)**:
#    - Cada trabalhador executa o ambiente independentemente.
#    - A cada `N_STEPS` ou quando o episódio termina, os trabalhadores:
#      - Calculam vantagens e retornos.
#      - Atualizam o modelo global (assincronicamente).
#      - Sincronizam o modelo local com o modelo global.
#
# 3. **Processos Paralelos**:
#    - A biblioteca `multiprocessing` é usada para executar vários trabalhadores em paralelo.
#    - `global_model.share_memory()` permite que os processos compartilhem o mesmo modelo global.
#
# 4. **Sincronização**:
#    - O gradiente é calculado localmente e aplicado ao modelo global.
#    - Após cada atualização, os pesos do modelo global são sincronizados com o modelo local.
#
# 5. **Coleta de Recompensas**:
#    - As recompensas de cada episódio são enviadas para uma fila (`results_queue`) para análise final.
#
# ---
#
# ### **Como Executar**
# 1. Salve o código em um arquivo Python, por exemplo, `a3c_cartpole.py`.
# 2. Execute com:
#    ```bash
#    python a3c_cartpole.py
#    ```
# 3. Observe os trabalhadores imprimindo recompensas para cada episódio.
#
# ---
#
# ### **Resultado Esperado**
# - O A3C treinará o modelo em paralelo, acelerando o aprendizado.
# - A recompensa média por episódio (`results`) será exibida no final do treinamento.
